# %%
import pyvo as vo
import numpy as np
from astropy.coordinates import SkyCoord
from astropy.nddata import Cutout2D
from astropy.wcs import WCS
import astropy.units as u
import matplotlib.pyplot as plt
from astropy.utils.data import download_file
from astropy.io import fits
from astropy.table import Table
from photutils.aperture import CircularAperture, CircularAnnulus, aperture_photometry
from photutils.utils import calc_total_error
import pandas as pd
from scipy.spatial import KDTree
import json


from scipy.optimize import curve_fit
from photutils.detection import DAOStarFinder
from astropy.stats import mad_std, sigma_clipped_stats
from astropy.visualization import SqrtStretch
from astropy.visualization.mpl_normalize import ImageNormalize
import math

# %%
# %matplotlib inline

# %% [markdown]
# # initialization of flux values so i can debug:

# %%
####Defining the constants

#define coordinates	
ra= 359.45700000000016
dec= -32.592000000000013
pos = SkyCoord(ra=ra, dec=dec, unit= 'deg')
print(pos)

# Lookup and define a service for ALLWISE Atlas images
# the website gave me the URL
allwise_service = vo.dal.SIAService("https://irsa.ipac.caltech.edu/ibe/sia/wise/allwise/p3am_cdd?")

#search the service for images covering within 1 arcsecond of the star. make this bigger if needed
im_table = allwise_service.search(pos=pos, size= 1*u.arcsec)
#im_table
im_table.to_table().colnames
for i in range(len(im_table)):
    print(im_table[i])


   #grab the x-ray sources for this galaxy
#import huge csv and grab the name and ra and dec needed for each source.
targetgals = pd.read_csv('../Data/inWISE.csv') # this should not be the one for all 120 and should rather be for the 74 of them.
print(targetgals[0:20])
huge = pd.read_csv('../Data/Hugefiles/Source_Flux_All_Modified_5.csv')
columns = ['RA','Dec', 'Gname_Modified','Gname_Homogenized']
g_huge = huge[columns]
g_huge[0:100]

#locate through merging
df1 = targetgals
df2 = g_huge

merged_data = pd.merge(df1, df2, left_on='source_id', right_on = 'Gname_Homogenized', how='inner')
columns = ['RA','Dec','Gname_Homogenized']
Xray_sources = merged_data[columns]
Xray_sources

# just want NGC 7793s sources
sources_7793 = Xray_sources.loc[Xray_sources['Gname_Homogenized'] == 'NGC 7793']
#sources_7793
#define the X-ray sources of NGC 7793
ra = sources_7793['RA'].values
dec = sources_7793['Dec'].values
#print(ra)

# defining a function to calculate the distances between two sources.
def dist(p1, p2):
    return np.sqrt( (p2[0] - p1[0])**2 + (p2[1] - p1[1])**2 )

#defining a function that creates a circular mask around each source so that if something overlaps with it, that overlapping part is not included in the aperture photometry
def create_circular_mask(h,w,center,radius):
    Y, X = np.ogrid[:h, :w] # creating an open (more memory efficient) coordinate grid of the image
    dist_from_center = np.sqrt((X-center[0])**2+ (Y-center[1])**2)
    mask = dist_from_center <= radius # so that everything inside the radius receives a mask
    return mask

# define a mapping of the bands into labels to make it easier
band_labels = {'w1': 'W1', 'w2': 'W2', 'w3': 'W3', 'w4': 'W4'}
flux_zmfd = {'w1': 309.54 ,'w2': 171.787,'w3': 31.674,'w4': 8.363} # check if these worked by looking at the band 4 code above
instr_zpmag = {'w1': 20.73,'w2': 19.56,'w3': 17.6 ,'w4':12.98 }
wavelengths = {'w1': 3.4 ,'w2': 4.6,'w3': 12,'w4': 22}

#define function to get flux density per unit frequency (energy units)
def flux_dens(net_flx, net_flx_err, wavelength):
    flux_density = (net_flx * 1e-23) * (3e10 / (wavelength*1e-4)**2)
    flux_density_unc = (net_flx_err * 1e-23) * (3e10 / (wavelength*1e-4)**2)
    return flux_density, flux_density_unc


##running the for loop over every image and doing aperture photometry on each one
#currently outputs as w4,w1,w2,w3 when querying the images. so index is 0.1.2.3 i want the index to be 0.3.2.1
rows = []
for i in [0, 3, 2, 1]:  # Reverse order index
    band_id = im_table[i]["sia_bp_id"].lower()  # Get band ID in lowercase

    if band_id in band_labels:
        print(f'Band {band_labels[band_id]}: ')
        data_url = im_table[i].getdataurl()
        #Download the image and open it in Astropy
        fname = download_file(data_url, cache=True)
        image1= fits.open(fname)
        image_data= image1[0].data
        #print(data)
        
        wcs = WCS(image1[0].header)
        #cuting out the image of the galaxy apart from the rest of the background.
        cutout = Cutout2D(image_data, pos, (437,437), wcs=wcs)
        wcs = cutout.wcs
        cutout_data = cutout.data
        #print(cutout_data)
        positions = wcs.world_to_pixel_values(ra, dec)
        positions = np.array(list(zip(positions[0], positions[1])))

        #define the distance threshold for the KDTree grouping (in pixels)
        distance_threshold = 5

        #build the KDTree for efficient grouping
        tree = KDTree(positions)

        #query the KDTree to find points within the defined radius of dist threshold and group them together
        groups = tree.query_ball_tree(tree, r=distance_threshold)
       # print(groups)
        # consolidating the groups. 'unique_groups' and 'seen': These are used to ensure that each group is processed only once.
        unique_groups = []
        seen = set()
        for group in groups:
            group = tuple(sorted(group))
            if group not in seen:
                seen.add(group)
                unique_groups.append(group)
       # print(unique_groups)
        # for each unique group, the average postion of the detections is calulated so that only one source detection is used for aperture photometry instead of a bunch of the same sources being used.
        #represents the consolidated postion of potentially multiple detections of one source.
        grouped_positions = [positions[list(group)].mean(axis=0) for group in unique_groups]
        #print(grouped_positions)

        #define the Region(s) Of Interest (center x, center y, radius)
        ROI = [ ((x, y) , 9, 16, 23) for x,y in grouped_positions ] # (x, y, radius around target, inner r, outer r)   36.3636, 50.90909) may need to mke the radius bigger when goruping? 
        

        # initialize valid rows plotting for the current image iteration
        valid_rows = []
        
        #now inputting the aperture photometry part
        # check for overlap and perform aperture photometry
        for i, ((x, y), r, annulus_inner, annulus_outer) in  enumerate(ROI):
            overlap = False# initialize overlap flag (A boolean flag overlap is set to False for each source to track if it overlaps with any other source.)
            non_overlapping_mask = create_circular_mask(cutout_data.shape[0], cutout_data.shape[1], (x,y), r)

            for j, ((x2, y2), r2, annulus_inner2, annulus_outer2) in  enumerate(ROI): # apparently you can run a for loop over 2 objects by putting the second one inside the first. it iterates over every source again to then see if it overlaps at all with another source.
                if i != j: # ensures that a source is not compared to itself! wow
                    distance = dist((x, y) , (x2, y2)) 
                    if distance < r + r2:  # if the distance is less than the size of the two radii added together, then they are overlapping.
                        overlap_percent = (r + r2 - distance)/(r+r2)  # the amount they are overlapping divided by the total size of radii distance
                        if overlap_percent > .5:
                            overlap = True # this way, if they overlap by more than 50% then they will not be usable because less than 50% of the flux extractable area can be seen.
                            overlap_mask = create_circular_mask(cutout_data.shape[0], cutout_data.shape[1], (x2,y2), r2)
                            non_overlapping_mask = np.logical_and(non_overlapping_mask, np.logical_not(overlap_mask)) # so that the overlapping part is read as false and thus excluded from calculation of flux.
                            # "logical and and not" are used to exclude certain regions such as the overlapping part! the logical not makes it so that 
                            # values that were once true in the overlap mask are not false, and the logical_and is there so that only the true values are accepted. effectively rejecting the part the overlapping mask covers.

                            #Handle overlaps that are acceptable (less than the threshold, but still overlapping by a small percent)
                            overlap_aperture = CircularAperture((x2, y2), r2)
                            overlap_photo_table = aperture_photometry(cutout_data, overlap_aperture)
                            overlap_counts = overlap_photo_table['aperture_sum'][0] 
                            overlap_error = np.sqrt(overlap_counts)
                            
                        else: 
                            overlap_mask = create_circular_mask(cutout_data.shape[0], cutout_data.shape[1], (x2,y2), r2)
                            non_overlapping_mask = np.logical_and(non_overlapping_mask, np.logical_not(overlap_mask))
                            overlap_aperture = CircularAperture((x2, y2), r2)
                            overlap_photo_table = aperture_photometry(cutout_data, overlap_aperture)
                            overlap_counts = overlap_photo_table['aperture_sum'][0] 
                            overlap_error = np.sqrt(overlap_counts)
                            
            if overlap:
                # For the Target objects in the little aperture circle define their target apertures
                target_aperture = CircularAperture((x,y),r,)
            
                #perform aperture photometry on target
                target_photo_table = aperture_photometry(cutout_data, target_aperture) 
                target_counts = target_photo_table['aperture_sum'][0]
                target_counts -= overlap_counts

                # so that i dont take the log or sqrt of a negative number or zero and get an error
                if target_counts > 0: # 
                    target_error= np.sqrt(target_counts)
                    #propagated error of overlap error
                    target_overlap_counts_err = np.sqrt(target_error**2 + overlap_error**2)
                    #print(target_counts)
                    if band_id in flux_zmfd and instr_zpmag: 
                         #print(f'Band {flux_zmfd[band_id]}: ')
                         flx_conv_fact = flux_zmfd[band_id]
                         M0instr = instr_zpmag[band_id]
                         Mcal_trgt = M0instr - 2.5*(np.log10(target_counts))     #converting counts to magnitude
                         target_flux = flx_conv_fact * 10**(Mcal_trgt/-2.5)      #convert Magnitude to Flux
                         
                         #propagation of uncertainty of flux conversion
                         Mcal_error = (2.5*target_overlap_counts_err) / (target_counts * np.log(10))
                         target_flux_error = target_flux * np.log(10) * (Mcal_error/2.5)

                else:
                         # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
                        rows.append({ 'band_id': {band_labels[band_id]},'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner, 
                        'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx, 'Flux Uncertainty': [], 'Flag':'Negative Target Counts',
                        'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
                            'Annulus Counts': annulus_counts, 'Overlap Counts': overlap_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
                            'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
                            'Offset in Arcseconds': [],  'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : []  })

                    
                #calculate area of target aperutue
                target_area = target_aperture.area




                # For the Background Annuli of outside of the Target
                #define the background annulus for the target
                annulus_aperture = CircularAnnulus((x, y), annulus_inner, annulus_outer)

                #perform aperture photometry on annuli
                annulus_photo_table = aperture_photometry(cutout_data, annulus_aperture)
                annulus_counts = annulus_photo_table['aperture_sum'][0]
                
            
                if annulus_counts > 0:
                    overlapannulus_error = np.sqrt(annulus_counts) # the error of the annulus for sources that overlap
                     # to avoid taking the log of zero or negative value
                    if band_id in flux_zmfd and instr_zpmag: 
                         #print(f'Band {flux_zmfd[band_id]}: ')
                         flx_conv_fact = flux_zmfd[band_id]
                         M0instr = instr_zpmag[band_id]
                         Mcal_trgt = M0instr - 2.5*(np.log10(annulus_counts))     #converting counts to magnitude
                         annulus_flux = flx_conv_fact * 10**(Mcal_trgt/-2.5)      #convert Magnitude to Flux

                         #propagation of uncertainty of flux conversion
                         Mcal_error_ann = (2.5 * overlapannulus_error) / (annulus_counts * np.log(10))
                         annulus_flux_error = annulus_flux * np.log(10) * (Mcal_error_ann/2.5)


                else:
                        annulus_flux = np.nan # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
                        
                #calculate area of annulus
                annulus_area = annulus_aperture.area

                # do the calculations for including a Background aperture
            
                #Calculating the net flux:
                #calculate the mean background per pixel
                bg_perpixel = annulus_flux/annulus_area
                bg_perpixel_err = annulus_flux_error/annulus_area #propagation of error!

                #calculate the total background in the target aperture
                tot_bg = bg_perpixel * target_area
                tot_bg_err = bg_perpixel_err * target_area ##propagation of error!

                #Subtract background from the target flux
                net_flx = target_flux - tot_bg
                net_flx_err = np.sqrt(target_flux_error**2 + tot_bg_err**2) ##propagation of error!
            
                #flag the sources that overlap
                rows.append({ 'band_id': {band_labels[band_id]},'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner, 
                        'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx,'Flux Uncertainty': net_flx_err, 'Flag':'Valid' if not math.isnan(target_counts) and target_counts > 0 and net_flx > 0 else 'Low Flux',
                        'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
                            'Annulus Counts': annulus_counts, 'Overlap Counts': overlap_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
                            'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr, 
                            'Offset in Arcseconds': [], 'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : [] })
                # Append valid results to valid_rows
                valid_rows.append({
                    'band_id': {band_labels[band_id]},
                    'Region': i+1, 'X': x, 'Y': y, 'Radius': r,
                    'Annulus_Inner_Radius': annulus_inner,
                    'Annulus_Outer_Radius': annulus_outer,
                    'Net Flux (Jy)': net_flx, 'Flux Uncertainty': net_flx_err,'Flag':'Valid' if not math.isnan(target_counts) and target_counts > 0 and net_flx > 0 else 'Low Flux', 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr, 
                    'Offset in Arcseconds': [], 'Exists?': 'No', 'Point Source Position' : [],  'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : [] })
                
            else: #perform all the aperture photometry stuff
                # For the Target objects in the little aperture circle define their target apertures
                target_aperture = CircularAperture((x,y),r,)
            
                #perform aperture photometry on target
                target_photo_table = aperture_photometry(cutout_data, target_aperture) 
                target_counts = target_photo_table['aperture_sum'][0]

                if target_counts > 0: # 
                    # avoid taking the log of zero or negative value
                    target_error = np.sqrt(target_counts)
                    if band_id in flux_zmfd and instr_zpmag: 
                         #print(f'Band {flux_zmfd[band_id]}: ')
                         flx_conv_fact = flux_zmfd[band_id]
                         M0instr = instr_zpmag[band_id]
                         Mcal_trgt = M0instr - 2.5*(np.log10(target_counts))     #converting counts to magnitude
                         target_flux = flx_conv_fact * 10**(Mcal_trgt/-2.5)      #convert Magnitude to Flux

                         #propagation of uncertainty of flux conversion
                         Mcal_error = (2.5*target_error) / (target_counts * np.log(10))
                         target_flux_error = target_flux * np.log(10) * (Mcal_error/2.5)

                else:
                         # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
                        rows.append({ 'band_id': {band_labels[band_id]},'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner, 
                        'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx,'Flux Uncertainty': [],'Flag':'Negative Target Counts',
                        'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
                            'Annulus Counts': annulus_counts, 'Overlap Counts': overlap_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
                            'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
                            'Offset in Arcseconds': [], 'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : [] })

                    
                #calculate area of target aperutue
                target_area = target_aperture.area




                # For the Background Annuli of outside of the Target
                #define the background annulus for the target
                annulus_aperture = CircularAnnulus((x, y), annulus_inner, annulus_outer)

                #perform aperture photometry on annuli
                annulus_photo_table = aperture_photometry(cutout_data, annulus_aperture)
                annulus_counts = annulus_photo_table['aperture_sum'][0]
                # the error of the annulus for sources that overlap
                
                if annulus_counts > 0:
                    annulus_error = np.sqrt(annulus_counts)
                     # avoid taking the log of zero or negative value
                    if band_id in flux_zmfd and instr_zpmag: 
                         #print(f'Band {flux_zmfd[band_id]}: ')
                         flx_conv_fact = flux_zmfd[band_id]
                         M0instr = instr_zpmag[band_id]
                         Mcal_trgt = M0instr - 2.5*(np.log10(annulus_counts))     #converting counts to magnitude
                         annulus_flux = flx_conv_fact * 10**(Mcal_trgt/-2.5)      #convert Magnitude to Flux

                         #propagation of uncertainty of flux conversion
                         Mcal_error_ann = (2.5 * annulus_error) / (annulus_counts * np.log(10))
                         annulus_flux_error = annulus_flux * np.log(10) * (Mcal_error_ann/2.5)
                else:
                        annulus_flux = np.nan # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
                        
               #calculate area of annulus
                annulus_area = annulus_aperture.area

                # do the calculations for including a Background aperture
            
                #Calculating the net flux:
                #calculate the mean background per pixel
                bg_perpixel = annulus_flux/annulus_area
                bg_perpixel_err = annulus_flux_error/annulus_area #propagation of error!

                #calculate the total background in the target aperture
                tot_bg = bg_perpixel * target_area
                tot_bg_err = bg_perpixel_err * target_area ##propagation of error!

                #Subtract background from the target flux
                net_flx = target_flux - tot_bg
                net_flx_err = np.sqrt(target_flux_error**2 + tot_bg_err**2) ##propagation of error!

                #   Append the result as a dictionary to the list named 'rows'
                rows.append({ 'band_id': {band_labels[band_id]},'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner, 
                        'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx, 'Flux Uncertainty': net_flx_err,  'Flag':'Valid' if not math.isnan(target_counts) and target_counts > 0 and net_flx > 0 else 'Low Flux',
                        'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
                            'Annulus Counts': annulus_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
                            'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
                              'Offset in Arcseconds': [],   'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': [], 'Wavelength': wavelengths[band_id],'Flux Density': [], 'Flux Density Uncertainty' : [] })  #will prolly have to change the name of the Flux here!!!
            #"Low Flux" means that they either have zero flux or negative flux and so they are excluded from the plotting
               
                # Append valid results to valid_rows
                valid_rows.append({
                    'band_id': {band_labels[band_id]},
                    'Region': i+1, 'X': x, 'Y': y, 'Radius': r,
                    'Annulus_Inner_Radius': annulus_inner,
                    'Annulus_Outer_Radius': annulus_outer,
                    'Net Flux (Jy)': net_flx, 'Flux Uncertainty': net_flx_err,
                    'Flag':'Valid' if not math.isnan(target_counts) and target_counts > 0 and net_flx > 0 else 'Low Flux', 
                    'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr, 'Exists?': 'No', 'Point Source Position' : [], 'Offset in Arcseconds': [],
                     'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': [], 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : [] })


        #Source detection code
        mean, median, std = sigma_clipped_stats(cutout_data, sigma=3.0)  
       #print((mean, median, std))

        # subtract the background and find FWHM of sources at a certain threshold
        #started at fwhm= 3 and threshold = 5
        daofind = DAOStarFinder(fwhm=8, threshold=1*std) # find the stars in the image that have FWHMs of around 3 pixels and have peaks approximately 5-sigma above the background. 
        sources = daofind(cutout_data - median)  
        #print(type(sources))
        # will likely run into iissues in the code below
        for col in sources.colnames:  
            if col not in ('id', 'npix'):
                sources[col].info.format = '%.2f'  # for consistent table output
       # sources.pprint(max_width=3000)  

        #likely the flux labeled in this is not converted!
        
        # plot the image with marked locations of all the sources it detected.
        detected_positions = np.transpose((sources['xcentroid'], sources['ycentroid']))
        apertures = CircularAperture(detected_positions, r=2)


        # Plotting for current image
        # Filter valid rows
        valid_rows_filtered = [row for row in valid_rows if row['Flag'] == 'Valid']
        
        # Was there a point source there?
        pixelsinarc = 0.0003819444391411 * 3600 ## 0.0003819444391411 is the number found in the header of the image for the scale of pixels in degrees for the fits image.
        detectedpos_all = []
        #rows = [row for row in rows if row['Flag'] == 'Valid']
        for row in valid_rows_filtered:
            apertures_forced = CircularAperture((row['X'], row['Y']), r=row['Radius'])
            for detected_position in detected_positions:
                detected_x, detected_y = detected_position
                distance = dist((row['X'], row['Y']), (detected_x, detected_y) ) #distance from the center of the xray source to the center of the detected source
                if distance <= row['Radius']: 
                    row['Exists?'] = 'Point Source Detected'
                    row['Point Source Position'].append((detected_x, detected_y))
                    dist_in_arc = distance * pixelsinarc
                    row['Offset in Arcseconds'].append((dist_in_arc))
                    detectedpos_all.append(detected_position) 
                    #print(f"Number of detected positions within forced apertures: {len(detectedpos_all)}")


        Yes = []
        YesRadius= 5
        for row in valid_rows_filtered:
                    apertures_forced = CircularAperture((row['X'], row['Y']), r=row['Radius'])
                    for detected_position in detected_positions:
                        detected_x, detected_y = detected_position
                        distance = dist((row['X'], row['Y']), (detected_x, detected_y) )

                        if distance <= YesRadius:
                            row['Exists?'] = 'Yes!!'
                            Yes.append((row['X'], row['Y']))
        #doing flux density
        for row in valid_rows_filtered:
             net_flx = row['Net Flux (Jy)']
             net_flx_err = row['Flux Uncertainty']
             wavelength = row['Wavelength']
             #print(net_flx)
             flux_density, flux_density_unc = flux_dens(net_flx, net_flx_err, wavelength)
             row['Flux Density'].append(flux_density)
             row['Flux Density Uncertainty'].append(flux_density_unc)
                 
        
        # Update rows with valid_rows_filtered information
        for valid_row in valid_rows_filtered:
            for row in rows:
                if row['band_id'] == valid_row['band_id'] and row['Region'] == valid_row['Region']:
                    row.update(valid_row)

        #print('valid sources', valid_rows_filtered)

        #print( len(detectedpos_all))
        if len(detectedpos_all) > 0:
            apertures_detected = CircularAperture(detectedpos_all, r=2)
        if len(Yes) > 0:
            apertures_Yes = CircularAperture(Yes, r=YesRadius)
        
       # xc = 244.422687	 #19.014239	
       # yc=  191.596758# 310.340772
    
'''
         # Plotting for current image
        fig, ax = plt.subplots(subplot_kw={'projection': wcs})
        norm = ImageNormalize(cutout.data, stretch=SqrtStretch())
        for row in valid_rows_filtered:
            target_aperture = CircularAperture((row['X'], row['Y']), row['Radius'])
            annulus_aperture = CircularAnnulus((row['X'], row['Y']), row['Annulus_Inner_Radius'], row['Annulus_Outer_Radius'])
            target_aperture.plot(color='red', lw=1.5, alpha=.5, ax=ax)
            annulus_aperture.plot(color='blue', lw=1.5, alpha=.5, ax=ax)
            
            apertures.plot(color='#98ff98', lw=.5, alpha=0.5) 
            apertures_detected.plot(color='#FF4500', lw=.5, alpha=0.5)  #  #FF69B4 for hot pink
            apertures_Yes.plot(color='green', lw=.5, alpha=0.5) 

            # curious ones
           # curious = CircularAperture((xc,yc),5)
           # curious.plot(color='red', lw=.5, alpha=0.5)
        ax.imshow(cutout.data, cmap='gray', norm=norm, interpolation='nearest')
        ax.set_xlabel('Right Ascension')
        ax.set_ylabel('Declination')
        plt.title(f'Band {band_labels[band_id]}')
        plt.show()
        yesses =[row for row in valid_rows_filtered if row['Exists?'] == 'Yes!!']
       '''

       

        
        



display_data = pd.DataFrame(rows)
display_data
#pd.set_option("display.max_rows", None)
#pd.set_option("display.max_columns", None)
print(len(display_data.loc[display_data['Flag']== 'Valid']))
print(len(display_data))
#display(display_data.loc[display_data['Flag']== 'Valid'])
#display(display_data)
print(len(display_data.loc[display_data['Flag']== 'Valid']))
# Out:
# <SkyCoord (ICRS): (ra, dec) in deg
#     (359.457, -32.592)>
# ('W4 Coadd 0000m334_ac51', 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w4-int-3.fits', '{"aws": {"bucket_name": "nasa-irsa-wise", "key":"wise/allwise/images/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w4-int-3.fits", "region": "us-west-2"}}', 2, 'image/fits', 0.0, -33.317778, array([4095, 4095], dtype=int32), array([2048., 2048.]), array([  0.      , -33.317778]), 'SIN', array([-0.00038194,  0.00038194]), array([-0.00038194, -0.        , -0.        ,  0.00038194]), 'W4', 2.209e-05, 2.336e-05, 1.984e-05, 'm', 13.0, 0.012, 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w4-unc-3.fits.gz', 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w4-cov-3.fits.gz', '0000m334_ac51')
# ('W1 Coadd 0000m334_ac51', 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w1-int-3.fits', '{"aws": {"bucket_name": "nasa-irsa-wise", "key":"wise/allwise/images/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w1-int-3.fits", "region": "us-west-2"}}', 2, 'image/fits', 0.0, -33.317778, array([4095, 4095], dtype=int32), array([2048., 2048.]), array([  0.      , -33.317778]), 'SIN', array([-0.00038194,  0.00038194]), array([-0.00038194, -0.        , -0.        ,  0.00038194]), 'W1', 3.35e-06, 3.78e-06, 3.13e-06, 'm', 20.5, 0.006, 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w1-unc-3.fits.gz', 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w1-cov-3.fits.gz', '0000m334_ac51')
# ('W2 Coadd 0000m334_ac51', 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w2-int-3.fits', '{"aws": {"bucket_name": "nasa-irsa-wise", "key":"wise/allwise/images/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w2-int-3.fits", "region": "us-west-2"}}', 2, 'image/fits', 0.0, -33.317778, array([4095, 4095], dtype=int32), array([2048., 2048.]), array([  0.      , -33.317778]), 'SIN', array([-0.00038194,  0.00038194]), array([-0.00038194, -0.        , -0.        ,  0.00038194]), 'W2', 4.6e-06, 5.19e-06, 4.02e-06, 'm', 19.5, 0.007, 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w2-unc-3.fits.gz', 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w2-cov-3.fits.gz', '0000m334_ac51')
# ('W3 Coadd 0000m334_ac51', 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w3-int-3.fits', '{"aws": {"bucket_name": "nasa-irsa-wise", "key":"wise/allwise/images/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w3-int-3.fits", "region": "us-west-2"}}', 2, 'image/fits', 0.0, -33.317778, array([4095, 4095], dtype=int32), array([2048., 2048.]), array([  0.      , -33.317778]), 'SIN', array([-0.00038194,  0.00038194]), array([-0.00038194, -0.        , -0.        ,  0.00038194]), 'W3', 1.156e-05, 1.627e-05, 7.6e-06, 'm', 18.0, 0.012, 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w3-unc-3.fits.gz', 'https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/00/0000/0000m334_ac51/0000m334_ac51-w3-cov-3.fits.gz', '0000m334_ac51')
#        ra_x   dec_x               source_id  cntr_01    dist_x      pang_x  \
# 0   201.365 -43.019                NGC 5128      1.0  0.830776  162.673944
# 1   184.741  47.303             MESSIER 106      3.0  5.022737  -43.454463
# 2   202.468  47.198             MESSIER 051      4.0  6.295556  -65.412743
# 3   148.963  69.679             MESSIER 082      5.0  4.934001   60.594118
# 4    67.704  64.848                NGC 1569      6.0  8.361842  -51.691199
# 5    11.888 -25.288                NGC 0253      8.0  0.993958  158.563643
# 6    35.639  42.349                NGC 0891     10.0  3.895011 -134.133495
# 7    49.328 -41.106  NGC 1291:[LFF2012] 084     11.0  7.368795 -164.984930
# 8   190.530  32.542                NGC 4631     12.0  9.053783   69.702218
# 9   192.721  41.120             MESSIER 094     13.0  1.409980   58.249431
# 10  196.365 -49.468                NGC 4945     14.0  1.444546  -95.506067
# 11  172.005  78.993               UGC 06456     16.0  3.261849 -157.154801
# 12  267.365  70.145                NGC 6503     17.0  5.957336 -101.168740
# 13  186.454  33.547                NGC 4395     18.0  1.088464 -108.113185
# 14  184.375  37.809                NGC 4244     20.0  8.423295 -132.064124
# 15  181.763  43.065                NGC 4111     21.0  2.534106    1.427312
# 16  187.630  41.650                NGC 4485     22.0  4.796021   37.282045
# 17  161.958  12.582             MESSIER 105     24.0  4.829860 -107.390842
# 18  114.216  65.600                NGC 2403     25.0  5.837017  145.062619
# 19  167.880  55.674             MESSIER 108     26.0  1.511374  -39.873393
#
#       ra_01  dec_01          designation        ra_y      dec_y   sigra  \
# 0   201.365 -43.019  J132527.62-430109.1  201.365094 -43.019220  0.0263
# 1   184.741  47.303  J121857.50+471814.4  184.739585  47.304013  0.0301
# 2   202.468  47.198  J132951.75+471155.4  202.465660  47.198728  0.0304
# 3   148.963  69.679  J095551.94+694046.8  148.966438  69.679673  0.0014
# 4    67.704  64.848  J043047.93+645057.9   67.699712  64.849440  0.0427
# 5    11.888 -25.288  J004733.14-251717.7   11.888112 -25.288257  0.0049
# 6    35.639  42.349  J022233.10+422053.6   35.637949  42.348247  0.0296
# 7    49.328 -41.106  J031718.55-410628.7   49.327296 -41.107977  0.0294
# 8   190.530  32.542  J124207.87+323234.3  190.532798  32.542872  0.0283
# 9   192.721  41.120  J125053.14+410712.7  192.721442  41.120206  0.0264
# 10  196.365 -49.468  J130527.45-492804.9  196.364385 -49.468038  0.0270
# 11  172.005  78.993  J112800.75+785931.7  172.003158  78.992165  0.0712
# 12  267.365  70.145  J174926.45+700840.8  267.360220  70.144679  0.0340
# 13  186.454  33.547  J122548.87+333248.8  186.453655  33.546906  0.0374
# 14  184.375  37.809  J121729.47+374826.7  184.372801  37.807432  0.0389
# 15  181.763  43.065  J120703.12+430356.5  181.763024  43.065704  0.0298
# 16  187.630  41.650  J123031.45+413903.8  187.631080  41.651060  0.0314
# 17  161.958  12.582  J104749.60+123453.7  161.956688  12.581599  0.0318
# 18  114.216  65.600  J073652.37+653555.2  114.218248  65.598671  0.0731
# 19  167.880  55.674  J111131.08+554027.5  167.879523  55.674322  0.0275
#
#     sigdec  sigradec  w1mpro  w1sigmpro  w1snr   w1rchi2  w2mpro  w2sigmpro  \
# 0   0.0252   -0.0031   5.262      0.051   21.1   19.1000   4.757      0.041
# 1   0.0302   -0.0049   8.530      0.023   47.4   50.1600   8.190      0.020
# 2   0.0294   -0.0027   9.855      0.023   46.9  123.7000   9.661      0.021
# 3   0.0014   -0.0003   3.669      0.383    2.8    0.2359   3.286      0.053
# 4   0.0393   -0.0248   9.450      0.028   38.3  442.4000   9.095      0.026
# 5   0.0039    0.0010   5.757      0.034   32.3   44.2100   5.028      0.029
# 6   0.0289   -0.0054   8.741      0.021   52.3  170.3000   8.161      0.019
# 7   0.0288    0.0050   7.194      0.027   40.4   68.6300   7.720      0.019
# 8   0.0282   -0.0052   9.175      0.022   50.4  149.4000   8.790      0.020
# 9   0.0263   -0.0044   5.611      0.048   22.6   31.2000   6.120      0.019
# 10  0.0254    0.0029   7.768      0.023   48.0   65.9500   6.498      0.020
# 11  0.0713    0.0160  15.125      0.033   32.7    4.8000  14.647      0.045
# 12  0.0359    0.0049  10.180      0.023   48.0   94.9500  10.102      0.022
# 13  0.0374   -0.0053  12.624      0.025   44.0    6.7480  11.839      0.023
# 14  0.0394   -0.0085  11.795      0.023   48.2   72.2700  11.835      0.024
# 15  0.0294   -0.0063   8.225      0.023   46.9   45.1200   8.221      0.019
# 16  0.0315   -0.0045  11.681      0.025   44.1   91.2200  11.381      0.022
# 17  0.0306   -0.0048   7.513      0.025   43.9   67.3700   7.868      0.020
# 18  0.0771   -0.0116  11.815      0.038   28.7   36.5100  11.619      0.038
# 19  0.0262   -0.0024  10.075      0.020   54.7  151.6000   9.602      0.018
#
#     w2snr  w2rchi2  w3mpro  w3sigmpro  w3snr   w3rchi2  w4mpro  w4sigmpro  \
# 0    26.4   12.230   2.621      0.012   89.4   20.4300   0.279      0.015
# 1    53.9   27.560   5.482      0.015   70.8    9.1490   3.328      0.020
# 2    52.7   86.920   5.366      0.013   83.2  114.0000   2.931      0.027
# 3    20.6   15.660  -1.666      0.321    3.4    0.1714  -4.348      0.001
# 4    42.3  324.400   5.004      0.017   65.3   75.3800   0.956      0.016
# 5    37.4   33.400   0.087      0.024   45.5    0.2416  -2.656      0.002
# 6    56.2  103.700   5.084      0.015   71.8   58.2400   2.955      0.026
# 7    56.2   56.470   6.691      0.015   72.3   26.1800   5.091      0.031
# 8    54.7   93.850   4.619      0.015   74.1   55.9200   1.799      0.015
# 9    56.3  109.100   4.337      0.013   83.0   59.1200   2.036      0.019
# 10   55.1   36.320   2.622      0.011  102.1   32.9600  -0.189      0.017
# 11   24.0    1.591  10.965      0.081   13.4    1.3500   6.886      0.068
# 12   50.4   56.850   7.698      0.022   48.9   33.6900   5.626      0.045
# 13   47.6    1.676   8.605      0.024   45.2    1.0370   5.519      0.037
# 14   46.1   19.030   9.271      0.038   28.9    3.7300   7.053      0.114
# 15   58.0   37.660   7.009      0.015   71.0   10.5800   5.229      0.030
# 16   49.6   39.960   6.651      0.015   71.1   45.2100   3.807      0.021
# 17   54.6   52.230   7.327      0.018   62.0   13.8300   6.195      0.047
# 18   28.5   18.400   8.784      0.070   15.6    4.8450   6.771      0.147
# 19   60.7   96.640   5.511      0.013   82.0  104.5000   2.512      0.022
#
#      w4snr    w4rchi2   nb   na  w1sat  w2sat  w3sat  w4sat    pmra  sigpmra  \
# 0     71.3    18.9800  1.0  0.0  0.100  0.097  0.075  0.000   -65.0     22.0
# 1     53.2     5.9670  1.0  0.0  0.000  0.000  0.000  0.000   218.0     47.0
# 2     40.0    57.7100  3.0  0.0  0.000  0.000  0.000  0.000   326.0     32.0
# 3   1253.0  5886.0000  1.0  0.0  0.219  0.161  0.328  0.441   -26.0     31.0
# 4     69.1    87.6300  3.0  0.0  0.000  0.000  0.000  0.000 -5809.0     42.0
# 5    515.7   371.4000  1.0  0.0  0.124  0.124  0.308  0.249 -1351.0     37.0
# 6     41.6    52.9100  2.0  0.0  0.000  0.000  0.000  0.000 -1700.0     27.0
# 7     35.3     3.1170  1.0  0.0  0.042  0.000  0.000  0.000  -131.0     22.0
# 8     70.3    81.4200  1.0  0.0  0.000  0.000  0.000  0.000 -4868.0     28.0
# 9     56.1    27.0900  1.0  0.0  0.097  0.040  0.000  0.000   245.0     26.0
# 10    65.4    27.8300  1.0  0.0  0.000  0.002  0.042  0.000    27.0     22.0
# 11    15.9     1.4390  2.0  0.0  0.000  0.000  0.000  0.000  -429.0    721.0
# 12    24.2    13.6500  2.0  0.0  0.000  0.000  0.000  0.000  -828.0     24.0
# 13    29.1     0.9281  1.0  0.0  0.000  0.000  0.000  0.000   103.0     46.0
# 14     9.5     1.1090  1.0  0.0  0.000  0.000  0.000  0.000  -170.0     56.0
# 15    36.1     1.1850  1.0  0.0  0.000  0.000  0.000  0.000    10.0     32.0
# 16    52.5    56.3000  1.0  0.0  0.000  0.000  0.000  0.000     0.0     39.0
# 17    23.0     1.5830  1.0  0.0  0.031  0.000  0.000  0.000  -193.0     37.0
# 18     7.4     1.3960  3.0  0.0  0.000  0.000  0.000  0.000   276.0     58.0
# 19    49.8    56.6700  2.0  0.0  0.000  0.000  0.000  0.000 -3041.0     28.0
#
#      pmdec  sigpmdec cc_flags  ext_flg var_flg ph_qual  moon_lev   w1nm  \
# 0   -305.0      22.0     hhhh      5.0    3344    AAAA       0.0   46.0
# 1   -347.0      60.0     0000      5.0    2211    AAAA       0.0   34.0
# 2  -1422.0      33.0     hh00      3.0    n3n4    AAAA       0.0   32.0
# 3   -107.0      30.0     hhhh      5.0    130n    CABA       0.0   39.0
# 4   -200.0      37.0     hhdd      3.0    nn23    AAAA       0.0   33.0
# 5    539.0      33.0     HHHH      5.0    nnnn    AAAA       0.0   27.0
# 6  -2463.0      26.0     hhhd      5.0    nn11    AAAA       0.0   27.0
# 7    -45.0      22.0     0000      5.0    3331    AAAA       0.0   65.0
# 8     95.0      29.0     hhhh      3.0    n333    AAAA      11.0   27.0
# 9   -494.0      25.0     hhh0      5.0    4n43    AAAA       0.0   33.0
# 10    -4.0      22.0     0hhh      5.0    2444    AAAA       0.0   50.0
# 11  -789.0     882.0     0000      1.0    0011    AAAA       0.0   51.0
# 12  -388.0      24.0     hhd0      5.0    3331    AAAA       0.0  151.0
# 13    93.0      47.0     0000      5.0    4500    AAAA       0.0   28.0
# 14  -468.0      63.0     0000      5.0    1000    AAAB       0.0   28.0
# 15   221.0      32.0     0000      5.0    3200    AAAA       0.0   29.0
# 16     0.0      39.0     000h      3.0    2124    AAAA       0.0   27.0
# 17  -362.0      34.0     0000      5.0    1100    AAAA    1100.0   24.0
# 18   538.0      61.0     ddPP      3.0    11nn    AAAB       0.0   32.0
# 19   -25.0      28.0     hhhd      5.0    n3n4    AAAA       0.0   33.0
#
#       w1m   w2nm    w2m  w3nm   w3m  w4nm   w4m _merge
# 0    46.0   46.0   46.0  24.0  24.0  24.0  24.0   both
# 1    34.0   34.0   34.0  19.0  19.0  19.0  19.0   both
# 2    32.0   32.0   32.0  18.0  18.0  18.0  18.0   both
# 3    39.0   39.0   39.0  19.0  19.0  19.0  19.0   both
# 4    33.0   33.0   33.0  17.0  17.0  17.0  17.0   both
# 5    27.0   27.0   27.0  14.0  14.0  14.0  14.0   both
# 6    27.0   27.0   27.0  12.0  12.0  12.0  12.0   both
# 7    65.0   65.0   65.0  33.0  33.0  33.0  33.0   both
# 8    27.0   27.0   27.0  14.0  14.0  14.0  14.0   both
# 9    33.0   33.0   33.0  18.0  18.0  18.0  18.0   both
# 10   50.0   50.0   50.0  27.0  27.0  27.0  27.0   both
# 11   51.0   50.0   51.0  16.0  25.0  24.0  25.0   both
# 12  151.0  151.0  151.0  77.0  77.0  77.0  77.0   both
# 13   28.0   28.0   28.0  15.0  15.0  15.0  15.0   both
# 14   28.0   27.0   27.0  14.0  14.0  13.0  14.0   both
# 15   29.0   29.0   29.0  16.0  16.0  16.0  16.0   both
# 16   27.0   27.0   27.0  15.0  15.0  15.0  15.0   both
# 17   24.0   24.0   24.0  13.0  13.0  13.0  13.0   both
# 18   32.0   32.0   32.0  17.0  17.0  11.0  17.0   both
# 19   33.0   33.0   33.0  20.0  20.0  20.0  20.0   both
# /var/folders/nd/77pj43rx7wbcbp0wx2qjq2140000gp/T/ipykernel_38896/507410234.py:25: DtypeWarning: Columns (533,534) have mixed types. Specify dtype option on import or set low_memory=False.
#   huge = pd.read_csv('../Data/Hugefiles/Source_Flux_All_Modified_5.csv')
# Band W4:
# Band W3:
# Band W2:
# Band W1:
# 109
# 780
# 109

# %% [markdown]
# # Debugging:

# %%
####Defining the constants
# defining a function to calculate the distances between two sources.
def dist(p1, p2):
   return np.sqrt( (p2[0] - p1[0])**2 + (p2[1] - p1[1])**2 )


#defining a function that creates a circular mask around each source so that if something overlaps with it, that overlapping part is not included in the aperture photometry
def create_circular_mask(h,w,center,radius):
   Y, X = np.ogrid[:h, :w] # creating an open (more memory efficient) coordinate grid of the image
   dist_from_center = np.sqrt((X-center[0])**2+ (Y-center[1])**2)
   mask = dist_from_center <= radius # so that everything inside the radius receives a mask
   return mask


# define a mapping of the bands into labels to make it easier
band_labels = {'w1': 'W1', 'w2': 'W2', 'w3': 'W3', 'w4': 'W4'}
flux_zmfd = {'w1': 309.54 ,'w2': 171.787,'w3': 31.674,'w4': 8.363} # check if these worked by looking at the band 4 code above
instr_zpmag = {'w1': 20.73,'w2': 19.56,'w3': 17.6 ,'w4':12.98 }
wavelengths = {'w1': 3.4 ,'w2': 4.6,'w3': 12,'w4': 22}


#define function to get flux density per unit frequency (energy units)
def flux_dens(net_flx, net_flx_err, wavelength):
   flux_density = (net_flx * 1e-23) * (3e10 / (wavelength*1e-4)**2)
   flux_density_unc = (net_flx_err * 1e-23) * (3e10 / (wavelength*1e-4)**2)
   return flux_density, flux_density_unc


'''
make a conditional code where:
choose one obs id and eerything associated with it bwith the longest exposuretime exptime?
tell me all of the obsids associated with this galaxy_name
    unique list of each galaxy Name
    what are the obs ids associated with it
    if more than one which one is the longest exposure
    aggregate all of the associated sources with it and none from any of the others


'''


#import huge csv and grab the name and ra and dec needed for each galaxy.
targetgals = pd.read_csv('../Data/inWISE.csv') # this should not be the one for all 120 and should rather be for the 74 of them.
#print(targetgals[0:20])
huge = pd.read_csv('../Data/Hugefiles/Source_Flux_All_Modified_5.csv')
columns = ['RA','Dec','Gname_Modified','Gname_Homogenized', 'ObsID', 'EXPOSURE']
g_huge = huge[columns]
#display(g_huge.head())


#group the x-ray sources for this galaxy. locate through merging
df1 = targetgals
df2 = g_huge




merged_data = pd.merge(df1, df2, left_on='source_id', right_on = 'Gname_Homogenized', how='inner')
columns1 = ['RA','Dec','Gname_Homogenized', 'ObsID', 'EXPOSURE']
Xray_sources = merged_data[columns1]


#group by galaxy name and the longest exposure time.
longest_exposure_obs = Xray_sources.loc[Xray_sources.groupby('Gname_Homogenized')['EXPOSURE'].idxmax()]


# aggregate all the sources associated with the obsid with the longest exposure time
aggregated_sources = Xray_sources[Xray_sources['ObsID'].isin(longest_exposure_obs['ObsID'])]




#align them based on source Id since they all got jumbled.
#aligned_targetgals = targetgals[targetgals.isin(aggregated_sources['Gname_Homogenized'])]


#reset index and group them by name
#aligned_targetgals = aligned_targetgals.reset_index(drop=True)
#print(aligned_targetgals)
#aligned_aggregatedsources = aggregated_sources.groupby('Gname_Homogenized')






'''
print("Unique list of each galaxy name:")
print(targetgals['source_id'])


print("\nObservations with the longest exposure time for each galaxy:")
print(longest_exposure_obs)


print("\nAggregated sources:")
print(aggregated_sources)
#'''












# Ensure the uniqueness for NGC 5128
#ngc_5128_sources = Xray_sources[Xray_sources['Gname_Homogenized'] == 'NGC 5128']
#print(f"Number of unique X-ray sources for NGC 5128: {len(ngc_5128_sources)}")
#print(ngc_5128_sources)


pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
#display(g_huge)
#display(Xray_sources)








#create a list of all the names needed
galaxy_names = targetgals['source_id'].unique()




galaxy_sources = {}
grouped_sources = aggregated_sources.groupby('Gname_Homogenized')
'''print("\nGrouped sources:")
for group_name, group in grouped_sources:
   print(f"\nGroup: {group_name}")
   print(group)'''
#get all of the ra and dec sources for the galaxy in question
for group_name, group in grouped_sources:
   galaxy_sources[group_name] = {'ra' : group['RA'].values, 'dec' : group['Dec'].values, 'ObsID': group['ObsID'].values}
  






#### initialize everything

#overlap_percent = []
#distance = []
























rows = []
#create subsets for testing:
grouped_sources_subset = grouped_sources.head(2)
targetgals_subset = targetgals.head(2)


#targetgals_subset = targetgals.iloc[17:18]


# Lookup and define a service for ALLWISE Atlas images
allwise_service = vo.dal.SIAService("https://irsa.ipac.caltech.edu/ibe/sia/wise/allwise/p3am_cdd?")
#loop through the galaxies
print("\nAligned target galaxies and grouped sources:")


for galaxy in targetgals_subset.itertuples():
   galaxy_name = galaxy.source_id
   print(galaxy_name)
   #group = aligned_aggregatedsources.get_group(galaxy_name)
  
   # Print galaxy information
   #print(f"\nGalaxy: {galaxy_name}")
   #print(group)


   #define coordinates
   ra1 = galaxy.ra_x
  #print (ra1)
   dec1 = galaxy.dec_x
   pos = SkyCoord(ra=ra1, dec=dec1, unit= 'deg')
   #search the service for images covering within 1 arcsecond of the star. make this bigger if needed
   im_table = allwise_service.search(pos=pos, size= 1*u.arcsec)
   #im_table
   im_table.to_table().colnames
   print(im_table)
   # get the Ra and dec values necessary for the kdtree and rest of the code
  
   if galaxy_name in galaxy_sources:
       ra = galaxy_sources[galaxy_name]['ra']
       dec = galaxy_sources[galaxy_name]['dec']
       obsid = galaxy_sources[galaxy_name]['ObsID']
       print(f"Galaxy: {galaxy_name}")
       print("RA values:", ra)
       print("Number of RA values:", len(ra))
   else:
       print(f"No sources found for galaxy: {galaxy_name}")
          
   ##running the for loop over every image and doing aperture photometry on each one
   #currently outputs as w4,w1,w2,w3 when querying the images. so index is 0.1.2.3 i want the index to be 0.3.2.1


   for i in [0, 3, 2, 1]:  # Reverse order index
       band_id = im_table[i]["sia_bp_id"].lower()  # Get band ID in lowercase


       if band_id in band_labels:
           print(f'Band {band_labels[band_id]}: ')
           data_url = im_table[i].getdataurl()
           #Download the image and open it in Astropy
           fname = download_file(data_url, cache=True)
           image1= fits.open(fname)
           image_data= image1[0].data
           #print(data)
           print(data_url)
           wcs = WCS(image1[0].header)
           #cuting out the image of the galaxy apart from the rest of the background.
           cutout = Cutout2D(image_data, pos, (437,437), wcs=wcs)
           wcs = cutout.wcs
           cutout_data = cutout.data
           #print(cutout_data)
           positions = wcs.world_to_pixel_values(ra, dec)
           positions = np.array(list(zip(positions[0], positions[1])))


           #define the distance threshold for the KDTree grouping (in pixels)
           distance_threshold = 6


           #build the KDTree for efficient grouping
           tree = KDTree(positions)


           #query the KDTree to find points within the defined radius of dist threshold and group them together
           groups = tree.query_ball_tree(tree, r=distance_threshold)
       # print(groups)
           # consolidating the groups. 'unique_groups' and 'seen': These are used to ensure that each group is processed only once.
           unique_groups = []
           seen = set()
           for group in groups:
               group = tuple(sorted(group))
               if group not in seen:
                   seen.add(group)
                   unique_groups.append(group)
       # print(unique_groups)
           # for each unique group, the average postion of the detections is calulated so that only one source detection is used for aperture photometry instead of a bunch of the same sources being used.
           #represents the consolidated postion of potentially multiple detections of one source.
           grouped_positions = [positions[list(group)].mean(axis=0) for group in unique_groups]
           #print(grouped_positions)


           #define the Region(s) Of Interest (center x, center y, radius)
           ROI = [ ((x, y) , 9, 16, 23) for x,y in grouped_positions ] # (x, y, radius around target, inner r, outer r)   36.3636, 50.90909) may need to mke the radius bigger when goruping?
          


           # initialize valid rows plotting for the current image iteration
           valid_rows = []
          
           #now inputting the aperture photometry part
           # check for overlap and perform aperture photometry
           for i, ((x, y), r, annulus_inner, annulus_outer) in  enumerate(ROI):
               overlap = False # initialize overlap flag (A boolean flag overlap is set to False for each source to track if it overlaps with any other source. becomes true if they do overlap 
               non_overlapping_mask = create_circular_mask(cutout_data.shape[0], cutout_data.shape[1], (x,y), r)

               acc_overlap = False # initialize the acceptable overlap flag.  false if there is no overlap, true if there is overlap and it is acceptable 


               for j, ((x2, y2), r2, annulus_inner2, annulus_outer2) in  enumerate(ROI): # apparently you can run a for loop over 2 objects by putting the second one inside the first. it iterates over every source again to then see if it overlaps at all with another source.
                   if i != j: # ensures that a source is not compared to itself! wow
                       distance = dist((x, y) , (x2, y2))
                       print('dsitance', distance)
                       if distance < r + r2:  # if the distance is less than the size of the two radii added together, then they are overlapping.
                           overlap_percent = (r + r2 - distance)/(r+r2)  # the amount they are overlapping divided by the total size of radii distance
                           print('overlap perc', overlap_percent)
                           if overlap_percent > .5:
                               overlap = True # this way, if they overlap by more than 50% then they will not be usable because less than 50% of the flux extractable area can be seen.
                               print('overlap is: ', overlap)
                               overlap_mask = np.nan
                               non_overlapping_mask = np.nan
                               overlap_aperture = np.nan
                               overlap_photo_table = np.nan
                               overlap_counts = np.nan
                               overlap_error = np.nan
                              
                           else:
                               if overlap_percent < .5:
                                    acc_overlap = True
                                    print('acceptable or no overlap: ', acc_overlap)
                                    overlap_mask = create_circular_mask(cutout_data.shape[0], cutout_data.shape[1], (x2,y2), r2)
                                    non_overlapping_mask = np.logical_and(non_overlapping_mask, np.logical_not(overlap_mask)) # so that the overlapping part is read as false and thus excluded from calculation of flux.
                                        # "logical and and not" are used to exclude certain regions such as the overlapping part! the logical not makes it so that
                                        # values that were once true in the overlap mask are not false, and the logical_and is there so that only the true values are accepted. effectively rejecting the part the overlapping mask covers.

                                     #Handle overlaps that are acceptable (less than the threshold, but still overlapping by a small percent)
                                    overlap_aperture = CircularAperture((x2, y2), r2)
                                    overlap_photo_table = aperture_photometry(cutout_data, overlap_aperture)
                                    overlap_counts = overlap_photo_table['aperture_sum'][0]
                                    overlap_error = np.sqrt(overlap_counts)


                       else:
                           print('Ran else')
               if acc_overlap:
                   # For the Target objects in the little aperture circle define their target apertures
                   target_aperture = CircularAperture((x,y),r,)
              
                   #perform aperture photometry on target
                   target_photo_table = aperture_photometry(cutout_data, target_aperture)
                   target_counts = target_photo_table['aperture_sum'][0]
                   target_counts -= overlap_counts


                   # so that i dont take the log or sqrt of a negative number or zero and get an error
                   if target_counts > 0: #
                       target_error= np.sqrt(target_counts)
                       #propagated error of overlap error
                       target_overlap_counts_err = np.sqrt(target_error**2 + overlap_error**2)
                       print(target_counts)
                       if band_id in flux_zmfd and instr_zpmag:
                           #print(f'Band {flux_zmfd[band_id]}: ')
                           flx_conv_fact = flux_zmfd[band_id]
                           M0instr = instr_zpmag[band_id]
                           Mcal_trgt = M0instr - 2.5*(np.log10(target_counts))     #converting counts to magnitude
                           target_flux = flx_conv_fact * 10**(Mcal_trgt/-2.5)      #convert Magnitude to Flux
                          
                           #propagation of uncertainty of flux conversion
                           Mcal_error = (2.5*target_overlap_counts_err) / (target_counts * np.log(10))
                           target_flux_error = target_flux * np.log(10) * (Mcal_error/2.5)


                   else:
                           # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
                           rows.append({ 'band_id': {band_labels[band_id]}, 'Galaxy Name' : galaxy_name, 'ObsID' : obsid[0], 'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner,
                           'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx, 'Flux Uncertainty': [], 'Flag':'Negative Target Counts',
                           'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
                               'Annulus Counts': annulus_counts, 'Overlap Counts': overlap_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
                               'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
                               'Offset in Arcseconds': [],  'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : []  })


                      
                   #calculate area of target aperutue
                   target_area = target_aperture.area








                   # For the Background Annuli of outside of the Target
                   #define the background annulus for the target
                   annulus_aperture = CircularAnnulus((x, y), annulus_inner, annulus_outer)


                   #perform aperture photometry on annuli
                   annulus_photo_table = aperture_photometry(cutout_data, annulus_aperture)
                   annulus_counts = annulus_photo_table['aperture_sum'][0]
                  
              
                   if annulus_counts > 0:
                       overlapannulus_error = np.sqrt(annulus_counts) # the error of the annulus for sources that overlap
                       # to avoid taking the log of zero or negative value
                       if band_id in flux_zmfd and instr_zpmag:
                           #print(f'Band {flux_zmfd[band_id]}: ')
                           flx_conv_fact = flux_zmfd[band_id]
                           M0instr = instr_zpmag[band_id]
                           Mcal_trgt = M0instr - 2.5*(np.log10(annulus_counts))     #converting counts to magnitude
                           annulus_flux = flx_conv_fact * 10**(Mcal_trgt/-2.5)      #convert Magnitude to Flux


                           #propagation of uncertainty of flux conversion
                           Mcal_error_ann = (2.5 * overlapannulus_error) / (annulus_counts * np.log(10))
                           annulus_flux_error = annulus_flux * np.log(10) * (Mcal_error_ann/2.5)




                   else:
                           annulus_flux = np.nan # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
                          
                   #calculate area of annulus
                   annulus_area = annulus_aperture.area


                   # do the calculations for including a Background aperture
              
                   #Calculating the net flux:
                   #calculate the mean background per pixel
                   bg_perpixel = annulus_flux/annulus_area
                   bg_perpixel_err = annulus_flux_error/annulus_area #propagation of error!


                   #calculate the total background in the target aperture
                   tot_bg = bg_perpixel * target_area
                   tot_bg_err = bg_perpixel_err * target_area ##propagation of error!


                   #Subtract background from the target flux
                   net_flx = target_flux - tot_bg
                   net_flx_err = np.sqrt(target_flux_error**2 + tot_bg_err**2) ##propagation of error!
              
                   #flag the sources that overlap
                   rows.append({ 'band_id': {band_labels[band_id]}, 'Galaxy Name' : galaxy_name, 'ObsID' : obsid[0], 'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner,
                           'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx,'Flux Uncertainty': net_flx_err, 'Flag':'Valid' if not math.isnan(target_counts) and target_counts > 0 and net_flx > 0 else 'Low Flux',
                           'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
                               'Annulus Counts': annulus_counts, 'Overlap Counts': overlap_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
                               'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
                               'Offset in Arcseconds': [], 'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : [] })
                   # Append valid results to valid_rows
                   valid_rows.append({
                       'band_id': {band_labels[band_id]},  'Galaxy Name' : galaxy_name, 'ObsID' : obsid[0],
                       'Region': i+1, 'X': x, 'Y': y, 'Radius': r,
                       'Annulus_Inner_Radius': annulus_inner,
                       'Annulus_Outer_Radius': annulus_outer,
                       'Net Flux (Jy)': net_flx, 'Flux Uncertainty': net_flx_err,'Flag':'Valid' if not math.isnan(target_counts) and target_counts > 0 and net_flx > 0 else 'Low Flux', 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
                       'Offset in Arcseconds': [], 'Exists?': 'No', 'Point Source Position' : [],  'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : [] })
                  
               else: #perform all the normal aperture photometry stuff for those that do not overlap in any way.
                   # For the Target objects in the little aperture circle define their target apertures
                   target_aperture = CircularAperture((x,y),r,)
              
                   #perform aperture photometry on target
                   target_photo_table = aperture_photometry(cutout_data, target_aperture)
                   target_counts = target_photo_table['aperture_sum'][0]


                   if target_counts > 0: #
                       # avoid taking the log of zero or negative value
                       target_error = np.sqrt(target_counts)
                       if band_id in flux_zmfd and instr_zpmag:
                           #print(f'Band {flux_zmfd[band_id]}: ')
                           flx_conv_fact = flux_zmfd[band_id]
                           M0instr = instr_zpmag[band_id]
                           Mcal_trgt = M0instr - 2.5*(np.log10(target_counts))     #converting counts to magnitude
                           target_flux = flx_conv_fact * 10**(Mcal_trgt/-2.5)      #convert Magnitude to Flux


                           #propagation of uncertainty of flux conversion
                           Mcal_error = (2.5*target_error) / (target_counts * np.log(10))
                           target_flux_error = target_flux * np.log(10) * (Mcal_error/2.5)


                   else:
                           # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
                           rows.append({ 'band_id': {band_labels[band_id]}, 'Galaxy Name' : galaxy_name, 'ObsID' : obsid[0], 'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner,
                           'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx,'Flux Uncertainty': [],'Flag':'Negative Target Counts',
                           'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
                               'Annulus Counts': annulus_counts, 'Overlap Counts': overlap_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
                               'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
                               'Offset in Arcseconds': [], 'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : [] })


                      
                   #calculate area of target aperutue
                   target_area = target_aperture.area








                   # For the Background Annuli of outside of the Target
                   #define the background annulus for the target
                   annulus_aperture = CircularAnnulus((x, y), annulus_inner, annulus_outer)


                   #perform aperture photometry on annuli
                   annulus_photo_table = aperture_photometry(cutout_data, annulus_aperture)
                   annulus_counts = annulus_photo_table['aperture_sum'][0]
                   # the error of the annulus for sources that overlap
                  
                   if annulus_counts > 0:
                       annulus_error = np.sqrt(annulus_counts)
                       # avoid taking the log of zero or negative value
                       if band_id in flux_zmfd and instr_zpmag:
                           #print(f'Band {flux_zmfd[band_id]}: ')
                           flx_conv_fact = flux_zmfd[band_id]
                           M0instr = instr_zpmag[band_id]
                           Mcal_trgt = M0instr - 2.5*(np.log10(annulus_counts))     #converting counts to magnitude
                           annulus_flux = flx_conv_fact * 10**(Mcal_trgt/-2.5)      #convert Magnitude to Flux


                           #propagation of uncertainty of flux conversion
                           Mcal_error_ann = (2.5 * annulus_error) / (annulus_counts * np.log(10))
                           annulus_flux_error = annulus_flux * np.log(10) * (Mcal_error_ann/2.5)
                   else:
                           annulus_flux = np.nan # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
                          
               #calculate area of annulus
                   annulus_area = annulus_aperture.area


                   # do the calculations for including a Background aperture
              
                   #Calculating the net flux:
                   #calculate the mean background per pixel
                   bg_perpixel = annulus_flux/annulus_area
                   bg_perpixel_err = annulus_flux_error/annulus_area #propagation of error!


                   #calculate the total background in the target aperture
                   tot_bg = bg_perpixel * target_area
                   tot_bg_err = bg_perpixel_err * target_area ##propagation of error!


                   #Subtract background from the target flux
                   net_flx = target_flux - tot_bg
                   net_flx_err = np.sqrt(target_flux_error**2 + tot_bg_err**2) ##propagation of error!


                   #   Append the result as a dictionary to the list named 'rows'
                   rows.append({ 'band_id': {band_labels[band_id]}, 'Galaxy Name' : galaxy_name, 'ObsID' : obsid[0], 'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner,
                           'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx, 'Flux Uncertainty': net_flx_err,  'Flag':'Valid' if not math.isnan(target_counts) and target_counts > 0 and net_flx > 0 else 'Low Flux',
                           'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
                               'Annulus Counts': annulus_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
                               'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
                               'Offset in Arcseconds': [],   'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': [], 'Wavelength': wavelengths[band_id],'Flux Density': [], 'Flux Density Uncertainty' : [] })  #will prolly have to change the name of the Flux here!!!
               #"Low Flux" means that they either have zero flux or negative flux and so they are excluded from the plotting
              
                   # Append valid results to valid_rows
                   valid_rows.append({
                       'band_id': {band_labels[band_id]}, 'Galaxy Name' : galaxy_name, 'ObsID' : obsid[0],
                       'Region': i+1, 'X': x, 'Y': y, 'Radius': r,
                       'Annulus_Inner_Radius': annulus_inner,
                       'Annulus_Outer_Radius': annulus_outer,
                       'Net Flux (Jy)': net_flx, 'Flux Uncertainty': net_flx_err,
                       'Flag':'Valid' if not math.isnan(target_counts) and target_counts > 0 and net_flx > 0 else 'Low Flux',
                       'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr, 'Exists?': 'No', 'Point Source Position' : [], 'Offset in Arcseconds': [],
                       'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': [], 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : [] })




           #Source detection code
           mean, median, std = sigma_clipped_stats(cutout_data, sigma=3.0) 
       #print((mean, median, std))


           # subtract the background and find FWHM of sources at a certain threshold
           #started at fwhm= 3 and threshold = 5
           daofind = DAOStarFinder(fwhm=8, threshold=1*std) # find the stars in the image that have FWHMs of around 3 pixels and have peaks approximately 5-sigma above the background.
           sources = daofind(cutout_data - median) 
           #print(type(sources))
           # will likely run into iissues in the code below
           for col in sources.colnames: 
               if col not in ('id', 'npix'):
                   sources[col].info.format = '%.2f'  # for consistent table output
       # sources.pprint(max_width=3000) 


           #likely the flux labeled in this is not converted!
          
           # plot the image with marked locations of all the sources it detected.
           detected_positions = np.transpose((sources['xcentroid'], sources['ycentroid']))
           apertures = CircularAperture(detected_positions, r=2)




           # Plotting for current image
           # Filter valid rows
           valid_rows_filtered = [row for row in valid_rows if row['Flag'] == 'Valid']
          
           # Was there a point source there?
           pixelsinarc = 0.0003819444391411 * 3600 ## 0.0003819444391411 is the number found in the header of the image for the scale of pixels in degrees for the fits image.
           detectedpos_all = []
           #rows = [row for row in rows if row['Flag'] == 'Valid']
           for row in valid_rows_filtered:
               apertures_forced = CircularAperture((row['X'], row['Y']), r=row['Radius'])
               for detected_position in detected_positions:
                   detected_x, detected_y = detected_position
                   distance = dist((row['X'], row['Y']), (detected_x, detected_y) ) #distance from the center of the xray source to the center of the detected source
                   if distance <= row['Radius']:
                       row['Exists?'] = 'Point Source Detected'
                       row['Point Source Position'].append((detected_x, detected_y))
                       dist_in_arc = distance * pixelsinarc
                       row['Offset in Arcseconds'].append((dist_in_arc))
                       detectedpos_all.append(detected_position)
                       #print(f"Number of detected positions within forced apertures: {len(detectedpos_all)}")




           Yes = []
           YesRadius= 5
           for row in valid_rows_filtered:
                       apertures_forced = CircularAperture((row['X'], row['Y']), r=row['Radius'])
                       for detected_position in detected_positions:
                           detected_x, detected_y = detected_position
                           distance = dist((row['X'], row['Y']), (detected_x, detected_y) )


                           if distance <= YesRadius:
                               row['Exists?'] = 'Yes!!'
                               Yes.append((row['X'], row['Y']))
           #doing flux density
           for row in valid_rows_filtered:
               net_flx = row['Net Flux (Jy)']
               net_flx_err = row['Flux Uncertainty']
               #print(net_flx)
               flux_density, flux_density_unc = flux_dens(net_flx, net_flx_err, wavelength)
               row['Flux Density'].append(flux_density)
               row['Flux Density Uncertainty'].append(flux_density_unc)
                  
          
           # Update rows with valid_rows_filtered information
           for valid_row in valid_rows_filtered:
               for row in rows:
                   if row['band_id'] == valid_row['band_id'] and row['Region'] == valid_row['Region']:
                       row.update(valid_row)


           #print('valid sources', valid_rows_filtered)


           #print( len(detectedpos_all))
           if len(detectedpos_all) > 0:
               apertures_detected = CircularAperture(detectedpos_all, r=2)
           if len(Yes) > 0:
               apertures_Yes = CircularAperture(Yes, r=YesRadius)
          
       # xc = 244.422687    #19.014239
       # yc=  191.596758# 310.340772
      
                

           # Plotting for current image
           '''
           fig, ax = plt.subplots(subplot_kw={'projection': wcs})
           norm = ImageNormalize(cutout.data, stretch=SqrtStretch())
           for row in valid_rows_filtered: # use valid_rows_filtered to change it back to only the valid sources.
               target_aperture = CircularAperture((row['X'], row['Y']), row['Radius'])
               annulus_aperture = CircularAnnulus((row['X'], row['Y']), row['Annulus_Inner_Radius'], row['Annulus_Outer_Radius'])
               target_aperture.plot(color='red', lw=1.5, alpha=.5, ax=ax)
               annulus_aperture.plot(color='blue', lw=1.5, alpha=.5, ax=ax)
              
               apertures.plot(color='#98ff98', lw=.5, alpha=0.5)
               apertures_detected.plot(color='#FF4500', lw=.5, alpha=0.5)  #  #FF69B4 for hot pink
               apertures_Yes.plot(color='green', lw=.5, alpha=0.5)


               # curious ones
           # curious = CircularAperture((xc,yc),5)
           # curious.plot(color='red', lw=.5, alpha=0.5)
           ax.imshow(cutout.data, cmap='gray', norm=norm, interpolation='nearest')
           ax.set_xlabel('Right Ascension')
           ax.set_ylabel('Declination')
           plt.title(f'Band {band_labels[band_id]}')
           plt.show()
           yesses =[row for row in valid_rows_filtered if row['Exists?'] == 'Yes!!']
           '''
   else:
       print('nothing worked')
           


  


      
      






display_data = pd.DataFrame(rows)
#by_name = display_data.groupby('Galaxy Name')
#byname = by_name.apply(lambda x: x).reset_index(drop=True)
#print("\n FINAL Sources Grouped by Galaxy:")
#display(byname)
#byname_byband = by_name.groupby('band_id')
#display(byname_byband)


#pd.set_option("display.max_rows", None)
#pd.set_option("display.max_columns", None)
print('Number of valid sources: ',len(display_data.loc[display_data['Flag']== 'Valid']))
print('Number of sources that dont 100 percent overlap x4 (because it is iterating over all 4 bands and appending each one once): ',len(display_data))
print('Number of sources coincidental with WISE bright points within 5 arcsec: ',len(display_data.loc[display_data['Exists?']== 'Yes!!']))
#display(display_data.loc[display_data['Flag']== 'Valid'])
display(display_data.loc[display_data['Exists?']== 'Yes!!'])
#display(display_data)
#print(len(display_data.loc[display_data['Flag']== 'Valid']))






  
#'''














'''
























#define coordinates
ra= 359.45700000000016
dec= -32.592000000000013
pos = SkyCoord(ra=ra, dec=dec, unit= 'deg')
#print(pos)


# Lookup and define a service for ALLWISE Atlas images
# the website gave me the URL
allwise_service = vo.dal.SIAService("https://irsa.ipac.caltech.edu/ibe/sia/wise/allwise/p3am_cdd?")


#search the service for images covering within 1 arcsecond of the star. make this bigger if needed
im_table = allwise_service.search(pos=pos, size= 1*u.arcsec)
#im_table
im_table.to_table().colnames
#for i in range(len(im_table)):
   #print(im_table[i])




#group the x-ray sources for this galaxy. locate through merging
df1 = targetgals
df2 = g_huge


merged_data = pd.merge(df1, df2, left_on='source_id', right_on = 'Gname_Homogenized', how='inner')
columns = ['RA','Dec','Gname_Homogenized']
Xray_sources = merged_data[columns]
Galaxies = Xray_sources.groupby(['Gname_Homogenized'])


# just want NGC 7793s sources
sources_7793 = Xray_sources.loc[Xray_sources['Gname_Homogenized'] == 'NGC 7793']
#sources_7793
#define the X-ray sources of NGC 7793
ra = sources_7793['RA'].values
dec = sources_7793['Dec'].values


# defining a function to calculate the distances between two sources.
def dist(p1, p2):
   return np.sqrt( (p2[0] - p1[0])**2 + (p2[1] - p1[1])**2 )


#defining a function that creates a circular mask around each source so that if something overlaps with it, that overlapping part is not included in the aperture photometry
def create_circular_mask(h,w,center,radius):
   Y, X = np.ogrid[:h, :w] # creating an open (more memory efficient) coordinate grid of the image
   dist_from_center = np.sqrt((X-center[0])**2+ (Y-center[1])**2)
   mask = dist_from_center <= radius # so that everything inside the radius receives a mask
   return mask


# define a mapping of the bands into labels to make it easier
band_labels = {'w1': 'W1', 'w2': 'W2', 'w3': 'W3', 'w4': 'W4'}
flux_zmfd = {'w1': 309.54 ,'w2': 171.787,'w3': 31.674,'w4': 8.363} # check if these worked by looking at the band 4 code above
instr_zpmag = {'w1': 20.73,'w2': 19.56,'w3': 17.6 ,'w4':12.98 }
wavelengths = {'w1': 3.4 ,'w2': 4.6,'w3': 12,'w4': 22}


#define function to get flux density per unit frequency (energy units)
def flux_dens(net_flx, net_flx_err, wavelength):
   flux_density = (net_flx * 1e-23) * (3e10 / (wavelength*1e-4)**2)
   flux_density_unc = (net_flx_err * 1e-23) * (3e10 / (wavelength*1e-4)**2)
   return flux_density, flux_density_unc


rows = []


#for galaxy in Galaxies:
  #  ra = galaxy['RA'].values
  #  dec = galaxy['Dec'].values
'''
# Out:
# /var/folders/nd/77pj43rx7wbcbp0wx2qjq2140000gp/T/ipykernel_38896/3567697035.py:45: DtypeWarning: Columns (533,534) have mixed types. Specify dtype option on import or set low_memory=False.
#   huge = pd.read_csv('../Data/Hugefiles/Source_Flux_All_Modified_5.csv')
# Aligned target galaxies and grouped sources:
# NGC 5128
# <DALResultsTable length=4>
#       sia_title        ...    coadd_id
#                        ...
#         object         ...     object
# ---------------------- ... -------------
# W4 Coadd 2022m425_ac51 ... 2022m425_ac51
# W2 Coadd 2022m425_ac51 ... 2022m425_ac51
# W1 Coadd 2022m425_ac51 ... 2022m425_ac51
# W3 Coadd 2022m425_ac51 ... 2022m425_ac51
# Galaxy: NGC 5128
# RA values: [201.23369464 201.23657077 201.25128439 201.25416886 201.2610683
#  201.26774089 201.26807596 201.26870325 201.26891047 201.27085808
#  201.271053   201.27125626 201.27607209 201.27751756 201.2797316
#  201.28065611 201.28167034 201.28392685 201.28742704 201.28818788
#  201.28958782 201.29404139 201.29652584 201.29780373 201.29912637
#  201.29988096 201.2999652  201.30128534 201.30361352 201.30796511
#  201.30823944 201.30842718 201.31119065 201.31161746 201.31400316
#  201.31528464 201.31563163 201.31557711 201.31668668 201.31790489
#  201.31822799 201.31930379 201.31981905 201.32045836 201.32054041
#  201.32085869 201.32136405 201.3224892  201.32311551 201.32371949
#  201.32411019 201.32493723 201.32692974 201.32718791 201.32756726
#  201.32780785 201.32892727 201.32925456 201.33042371 201.33179986
#  201.33221653 201.33231673 201.3325199  201.33336626 201.334623
#  201.33602726 201.33647435 201.33666558 201.33747806 201.33827958
#  201.33845762 201.33883567 201.3394623  201.33966498 201.34037789
#  201.34045921 201.34068964 201.3423254  201.34244061 201.34277205
#  201.34298407 201.34342401 201.34354218 201.34434922 201.34509396
#  201.34519671 201.34575747 201.34593719 201.34596573 201.34726085
#  201.3473741  201.34785644 201.34798945 201.34809501 201.34845408
#  201.34854631 201.349207   201.34959165 201.35042991 201.35044332
#  201.35053743 201.35114642 201.35128902 201.35168018 201.35213944
#  201.35254433 201.35310026 201.35310788 201.35312424 201.35323928
#  201.35388086 201.35461776 201.35464312 201.35495296 201.35515326
#  201.35576905 201.35623577 201.3572703  201.3573618  201.3579739
#  201.3588177  201.35885756 201.36000227 201.36019976 201.36068561
#  201.36197652 201.36208647 201.36230979 201.36243131 201.36268838
#  201.36366322 201.36414595 201.36421368 201.36440348 201.36443229
#  201.36466195]
# Number of RA values: 136
# Band W4:
# https://irsa.ipac.caltech.edu/ibe/data/wise/allwise/p3am_cdd/20/2022/2022m425_ac51/2022m425_ac51-w4-int-3.fits
# dsitance 228.89662372988857
# Ran else
# dsitance 157.66937145881082
# Ran else
# dsitance 168.2391773661242
# Ran else
# dsitance 53.59467155143725
# Ran else
# dsitance 140.17271864432786
# Ran else
# dsitance 152.40039768555584
# Ran else
# dsitance 90.80970417901045
# Ran else
# dsitance 97.09807411374544
# Ran else
# dsitance 94.31559684743742
# Ran else
# dsitance 103.14224103967187
# Ran else
# dsitance 108.6782174712105
# Ran else
# dsitance 85.62587037805731
# Ran else
# dsitance 217.75856217083125
# Ran else
# dsitance 93.02353337896697
# Ran else
# dsitance 103.4902142260643
# Ran else
# dsitance 118.71266983937154
# Ran else
# dsitance 136.4866081250884
# Ran else
# dsitance 246.07209106318808
# Ran else
# dsitance 203.09477725191562
# Ran else
# dsitance 153.06850831089753
# Ran else
# dsitance 188.7099949082319
# Ran else
# dsitance 247.0132946702973
# Ran else
# dsitance 124.92320722436766
# Ran else
# dsitance 171.87551808114281
# Ran else
# dsitance 176.0875470312947
# Ran else
# dsitance 159.97550237731548
# Ran else
# dsitance 238.40935317631653
# Ran else
# dsitance 153.8240701181142
# Ran else
# dsitance 240.89563066433337
# Ran else
# dsitance 159.21946959393222
# Ran else
# dsitance 143.462264853481
# Ran else
# dsitance 239.91859625336647
# Ran else
# dsitance 274.4623486599495
# Ran else
# dsitance 270.7435015942955
# Ran else
# dsitance 269.9283374010424
# Ran else
# dsitance 279.95355464742363
# Ran else
# dsitance 162.59827907009858
# Ran else
# dsitance 268.43054607431736
# Ran else
# dsitance 266.9287777408803
# Ran else
# dsitance 161.74434676162124
# Ran else
# dsitance 265.62097680826946
# Ran else
# dsitance 220.6966007624403
# Ran else
# dsitance 264.9319879105716
# Ran else
# dsitance 207.73704155610537
# Ran else
# dsitance 181.0966608053876
# Ran else
# dsitance 186.3533365084235
# Ran else
# dsitance 261.64687642439657
# Ran else
# dsitance 261.31886200372674
# Ran else
# dsitance 176.17541879843463
# Ran else
# dsitance 260.96755674749784
# Ran else
# dsitance 193.43879593970837
# Ran else
# dsitance 258.4104959095636
# Ran else
# dsitance 183.6830935011659
# Ran else
# dsitance 190.27843412509324
# Ran else
# dsitance 257.0023747034811
# Ran else
# dsitance 192.17655975988606
# Ran else
# dsitance 255.3055508073843
# Ran else
# dsitance 196.7845428223968
# Ran else
# dsitance 209.60228135503436
# Ran else
# dsitance 254.99638687887253
# Ran else
# dsitance 254.6924861127823
# Ran else
# dsitance 215.72671134547107
# Ran else
# dsitance 253.5886579144895
# Ran else
# dsitance 253.53537341856577
# Ran else
# dsitance 253.4641036576669
# Ran else
# dsitance 253.27161524719378
# Ran else
# dsitance 207.38082146070533
# Ran else
# dsitance 253.21976033671885
# Ran else
# dsitance 253.07690770028788
# Ran else
# dsitance 205.42860162721587
# Ran else
# dsitance 219.9274701972851
# Ran else
# dsitance 252.86732104768137
# Ran else
# dsitance 208.06161120139157
# Ran else
# dsitance 252.81995260312044
# Ran else
# dsitance 324.4439130883671
# Ran else
# dsitance 222.3864636309491
# Ran else
# dsitance 212.79719588366837
# Ran else
# dsitance 252.8489151076979
# Ran else
# dsitance 252.87050802931378
# Ran else
# dsitance 243.396552529239
# Ran else
# dsitance 253.02968462739597
# Ran else
# dsitance 224.7508843048814
# Ran else
# dsitance 221.29231151607857
# Ran else
# dsitance 344.52100608824486
# Ran else
# dsitance 253.1843497258509
# Ran else
# dsitance 225.8607017158763
# Ran else
# dsitance 252.84563354981663
# Ran else
# dsitance 222.90158903764328
# Ran else
# dsitance 220.41290221096443
# Ran else
# dsitance 253.09951691527408
# Ran else
# dsitance 229.2000354723337
# Ran else
# dsitance 238.28490468750547
# Ran else
# dsitance 230.2269926170496
# Ran else
# dsitance 253.7498828225291
# Ran else
# dsitance 254.35837541319057
# Ran else
# dsitance 238.48365824920512
# Ran else
# dsitance 254.56249607427662
# Ran else
# dsitance 230.19379207097754
# Ran else
# dsitance 239.72492682708582
# Ran else
# dsitance 228.54681219220353
# Ran else
# dsitance 262.22031315158733
# Ran else
# dsitance 255.32741238731063
# Ran else
# dsitance 255.52577831507742
# Ran else
# dsitance 255.74719942432358
# Ran else
# dsitance 241.3179265806453
# Ran else
# dsitance 244.2406642731815
# Ran else
# dsitance 233.84283177472636
# Ran else
# dsitance 256.5513447319527
# Ran else
# dsitance 242.69906482385497
# Ran else
# dsitance 257.52238928954773
# Ran else
# dsitance 280.0165870532179
# Ran else
# dsitance 257.9002618785556
# Ran else
# dsitance 249.6408592785755
# Ran else
# dsitance 260.2060280672542
# Ran else
# dsitance 252.80081719405663
# Ran else
# dsitance 276.43018489536774
# Ran else
# dsitance 261.2429282844401
# Ran else
# dsitance 268.94588536962215
# Ran else
# dsitance 250.60729916956012
# Ran else
# dsitance 316.9436941192493
# Ran else
# dsitance 271.17680180024456
# Ran else
# dsitance 251.84228139329161
# Ran else
# dsitance 279.5542157685094
# Ran else
# dsitance 258.71394540208865
# Ran else
# dsitance 228.89662372988857
# Ran else
# dsitance 383.8960591769804
# Ran else
# dsitance 73.36874099726928
# Ran else
# dsitance 244.74223581334618
# Ran else
# dsitance 357.9363154964965
# Ran else
# dsitance 371.21491718076453
# Ran else
# dsitance 178.39674467510338
# Ran else
# dsitance 170.49311570086894
# Ran else
# dsitance 298.0855146608395
# Ran else
# dsitance 167.92203233313464
# Ran else
# dsitance 161.51531603811145
# Ran else
# dsitance 267.2525847669396
# Ran else
# dsitance 83.03526248982817
# Ran else
# dsitance 215.30111135214565
# Ran else
# dsitance 196.430453777466
# Ran else
# dsitance 316.0857035114566
# Ran else
# dsitance 159.94957711257464
# Ran else
# dsitance 97.29686750277962
# Ran else
# dsitance 415.0072250863507
# Ran else
# dsitance 156.49490026167987
# Ran else
# dsitance 135.5820099714266
# Ran else
# dsitance 115.27617091317285
# Ran else
# dsitance 278.3348421742399
# Ran else
# dsitance 163.1349461936977
# Ran else
# dsitance 371.43523562156525
# Ran else
# dsitance 348.13103486518634
# Ran else
# dsitance 446.5743825344284
# Ran else
# dsitance 330.59862463415897
# Ran else
# dsitance 140.63624141826222
# Ran else
# dsitance 329.42331093230945
# Ran else
# dsitance 277.0730598008125
# Ran else
# dsitance 441.12020848207374
# Ran else
# dsitance 481.12887286599056
# Ran else
# dsitance 474.9299687474963
# Ran else
# dsitance 473.52599092721533
# Ran else
# dsitance 484.89868265969824
# Ran else
# dsitance 311.4192760672714
# Ran else
# dsitance 470.87674581192545
# Ran else
# dsitance 468.14438994243653
# Ran else
# dsitance 279.1659769921147
# Ran else
# dsitance 465.6514779003935
# Ran else
# dsitance 407.93186721444073
# Ran else
# dsitance 464.3213956798524
# Ran else
# dsitance 388.21627460954994
# Ran else
# dsitance 340.00218409422854
# Ran else
# dsitance 349.8116027646604
# Ran else
# dsitance 457.59633151576094
# Ran else
# dsitance 456.82629756931806
# Ran else
# dsitance 253.93217551932727
# Ran else
# dsitance 456.0507294958241
# Ran else
# dsitance 349.3085888592098
# Ran else
# dsitance 449.9610622590977
# Ran else
# dsitance 318.92890635599736
# Ran else
# dsitance 336.45974897756554
# Ran else
# dsitance 446.09906209126063
# Ran else
# dsitance 328.18684689722426
# Ran else
# dsitance 440.28289527279424
# Ran else
# dsitance 338.85783887501947
# Ran else
# dsitance 368.1808259866974
# Ran else
# dsitance 439.0909305313196
# Ran else
# dsitance 437.82631993269445
# Ran else
# dsitance 371.6692080149317
# Ran else
# dsitance 432.75327648747395
# Ran else
# dsitance 432.22409359188555
# Ran else
# dsitance 431.70249505583166
# Ran else
# dsitance 430.6354295328016
# Ran else
# dsitance 337.43194636773654
# Ran else
# dsitance 430.06464304007875
# Ran else
# dsitance 428.75971834651375
# Ran else
# dsitance 327.760025622423
# Ran else
# dsitance 246.79005579472238
# Ran else
# dsitance 426.2571555460697
# Ran else
# dsitance 312.777931860872
# Ran else
# dsitance 424.17068617120395
# Ran else
# dsitance 518.5859502071578
# Ran else
# dsitance 362.31533499499756
# Ran else
# dsitance 333.4494867199078
# Ran else
# dsitance 422.33429265761555
# Ran else
# dsitance 420.5982584885588
# Ran else
# dsitance 403.69076664480355
# Ran else
# dsitance 418.72961555385683
# Ran else
# dsitance 357.61934536304256
# Ran else
# dsitance 351.06185489964
# Ran else
# dsitance 539.377599519938
# Ran else
# dsitance 416.880658744628
# Ran else
# dsitance 357.5396155896986
# Ran else
# dsitance 414.6283625858449
# Ran else
# dsitance 334.80736187970575
# Ran else
# dsitance 299.1648348858961
# Ran else
# dsitance 413.1449245189771
# Ran else
# dsitance 358.0921947707718
# Ran else
# dsitance 382.8037628082256
# Ran else
# dsitance 358.2840213702875
# Ran else
# dsitance 411.2040369532012
# Ran else
# dsitance 410.9332049498021
# Ran else
# dsitance 377.9750623053858
# Ran else
# dsitance 410.27561311117825
# Ran else
# dsitance 345.2178053091607
# Ran else
# dsitance 371.8188831344428
# Ran else
# dsitance 324.0104761603157
# Ran else
# dsitance 421.1596288539651
# Ran else
# dsitance 407.9962885558653
# Ran else
# dsitance 407.3859050239419
# Ran else
# dsitance 406.759864474196
# Ran else
# dsitance 373.14168857206784
# Ran else
# dsitance 379.8820470223199
# Ran else
# dsitance 341.14583088778147
# Ran else
# dsitance 404.7939415369387
# Ran else
# dsitance 373.9035690062495
# Ran else
# dsitance 402.85836666029525
# Ran else
# dsitance 443.38287005620447
# Ran else
# dsitance 402.18888306927016
# Ran else
# dsitance 375.9694500737442
# Ran else
# dsitance 398.83459289799595
# Ran else
# dsitance 383.2756447534066
# Ran else
# dsitance 429.13355566595095
# Ran else
# dsitance 393.56306059606817
# Ran else
# dsitance 413.87286374128024
# Ran else
# dsitance 363.69869815734177
# Ran else
# dsitance 489.778015012991
# Ran else
# dsitance 272.88251553110973
# Ran else
# dsitance 357.6320765486612
# Ran else
# dsitance 265.3711743411191
# Ran else
# dsitance 382.9706992998985
# Ran else
# dsitance 157.66937145881082
# Ran else
# dsitance 383.8960591769804
# Ran else
# dsitance 317.7011416148611
# Ran else
# dsitance 143.86753580513192
# Ran else
# dsitance 43.45598615203888
# Ran else
# dsitance 36.1720879490215
# Ran else
# dsitance 217.93546866321765
# Ran else
# dsitance 226.4942039946793
# Ran else
# dsitance 99.40896223774894
# Ran else
# dsitance 231.52549403132812
# Ran else
# dsitance 238.6584649691721
# Ran else
# dsitance 135.10838191773956
# Ran else
# dsitance 358.55527819722545
# Ran else
# dsitance 191.88228762211259
# Ran else
# dsitance 212.97578852572977
# Ran else
# dsitance 97.92131575733887
# Ran else
# dsitance 258.6359266151249
# Ran else
# dsitance 383.9122345171122
# Ran else
# dsitance 73.51099641733049
# Ran else
# dsitance 273.5927771957199
# Ran else
# dsitance 314.18312995011274
# Ran else
# dsitance 379.85837677879744
# Ran else
# dsitance 157.8573615639839
# Ran else
# dsitance 286.85571425319574
# Ran else
# dsitance 98.30711739942333
# Ran else
# dsitance 109.00349397378851
# Ran else
# dsitance 106.32979978991892
# Ran else
# dsitance 127.04805013757979
# Ran else
# dsitance 365.0950815057537
# Ran else
# dsitance 137.2136282392708
# Ran else
# dsitance 179.4335991966481
# Ran else
# dsitance 119.81249515589941
# Ran else
# dsitance 138.5041145771978
# Ran else
# dsitance 139.09493832445904
# Ran else
# dsitance 139.3159519628117
# Ran else
# dsitance 145.77586745965974
# Ran else
# dsitance 165.42378943909802
# Ran else
# dsitance 139.84957593311427
# Ran else
# dsitance 140.528204929338
# Ran else
# dsitance 198.36111636076126
# Ran else
# dsitance 141.31533948898786
# Ran else
# dsitance 131.43971927363188
# Ran else
# dsitance 141.76327014676656
# Ran else
# dsitance 135.83358293743112
# Ran else
# dsitance 157.1988818680934
# Ran else
# dsitance 152.6935596868309
# Ran else
# dsitance 144.5536902820254
# Ran else
# dsitance 144.98962772335324
# Ran else
# dsitance 236.17495437401064
# Ran else
# dsitance 145.38095942957494
# Ran else
# dsitance 165.10116339005637
# Ran else
# dsitance 148.92733465252948
# Ran else
# dsitance 186.22422422405396
# Ran else
# dsitance 175.94345878829034
# Ran else
# dsitance 151.65414903127984
# Ran else
# dsitance 188.26408997694904
# Ran else
# dsitance 156.6488375427055
# Ran else
# dsitance 183.10861648685795
# Ran else
# dsitance 168.0541641583537
# Ran else
# dsitance 157.7442458371566
# Ran else
# dsitance 158.95273255129803
# Ran else
# dsitance 174.24487013140396
# Ran else
# dsitance 163.977816623071
# Ran else
# dsitance 164.62485889798242
# Ran else
# dsitance 165.2215221140214
# Ran else
# dsitance 166.33982539790972
# Ran else
# dsitance 200.7685572721192
# Ran else
# dsitance 167.04144405223073
# Ran else
# dsitance 168.5866279467342
# Ran else
# dsitance 207.99489025256008
# Ran else
# dsitance 291.21017197170454
# Ran else
# dsitance 171.64845608107873
# Ran else
# dsitance 226.19607494679357
# Ran else
# dsitance 174.42230334592702
# Ran else
# dsitance 198.9888888021982
# Ran else
# dsitance 196.7545558754126
# Ran else
# dsitance 212.95020892393802
# Ran else
# dsitance 176.9737085749859
# Ran else
# dsitance 179.3460331227565
# Ran else
# dsitance 183.31316121183977
# Ran else
# dsitance 182.1344004265972
# Ran else
# dsitance 205.80629900737975
# Ran else
# dsitance 207.4539946440903
# Ran else
# dsitance 215.90870609283536
# Ran else
# dsitance 184.85275308740577
# Ran else
# dsitance 207.65659447359891
# Ran else
# dsitance 187.11406353714793
# Ran else
# dsitance 226.40800024913676
# Ran else
# dsitance 254.46567386687198
# Ran else
# dsitance 189.49137656909596
# Ran else
# dsitance 212.3522984560973
# Ran else
# dsitance 199.75262163570915
# Ran else
# dsitance 213.77109000175378
# Ran else
# dsitance 193.15877769583898
# Ran else
# dsitance 194.63065458626627
# Ran else
# dsitance 205.64610402873075
# Ran else
# dsitance 195.82415972583186
# Ran else
# dsitance 227.06983363140512
# Ran else
# dsitance 214.5275283768427
# Ran else
# dsitance 244.48376904811929
# Ran else
# dsitance 196.6673143530467
# Ran else
# dsitance 200.02089704558588
# Ran else
# dsitance 201.12084544784133
# Ran else
# dsitance 202.27652914538768
# Ran else
# dsitance 215.70357387824802
# Ran else
# dsitance 213.17393069173355
# Ran else
# dsitance 236.43775077674013
# Ran else
# dsitance 206.06662915846266
# Ran else
# dsitance 217.1447151992079
# Ran else
# dsitance 210.0628284721646
# Ran else
# dsitance 203.17914010104516
# Ran else
# dsitance 211.50566207070523
# Ran else
# dsitance 226.291421497435
# Ran else
# dsitance 219.34020865999386
# Ran else
# dsitance 223.7589236667678
# Ran else
# dsitance 213.6665161300256
# Ran else
# dsitance 226.88810745846038
# Ran else
# dsitance 217.76308815443105
# Ran else
# dsitance 240.23128330349903
# Ran else
# dsitance 219.3498316842074
# Ran else
# dsitance 338.21763868932555
# Ran else
# dsitance 247.94729638319671
# Ran else
# dsitance 353.26647874809674
# Ran else
# dsitance 233.83974894943617
# Ran else
# dsitance 168.2391773661242
# Ran else
# dsitance 73.36874099726928
# Ran else
# dsitance 317.7011416148611
# Ran else
# dsitance 175.50611926165112
# Ran else
# dsitance 288.8964212383154
# Ran else
# dsitance 302.255155596708
# Ran else
# dsitance 105.98880722144654
# Ran else
# dsitance 97.83118193647059
# Ran else
# dsitance 227.82360157580732
# Ran else
# dsitance 94.89652749135409
# Ran else
# dsitance 88.33550186133239
# Ran else
# dsitance 195.68521087943938
# Ran else
# dsitance 58.202876041525705
# Ran else
# dsitance 142.31198084292194
# Ran else
# dsitance 123.1237700876036
# Ran else
# dsitance 244.60628405306474
# Ran else
# dsitance 87.6409105823069
# Ran else
# dsitance 87.38842773405577
# Ran else
# dsitance 344.09325083925444
# Ran else
# dsitance 86.63708184845433
# Ran else
# dsitance 77.53726016697173
# Ran else
# dsitance 96.3207445149152
# Ran else
# dsitance 205.05273287447727
# Ran else
# dsitance 97.37353444464127
# Ran else
# dsitance 299.00823662533185
# Ran else
# dsitance 275.431384512912
# Ran else
# dsitance 374.8642914404098
# Ran else
# dsitance 257.5132781648658
# Ran else
# dsitance 107.36793998324607
# Ran else
# dsitance 256.15751406650713
# Ran else
# dsitance 203.79657020162617
# Ran else
# dsitance 368.689508618525
# Ran else
# dsitance 409.0460489682912
# Ran else
# dsitance 402.6109173514919
# Ran else
# dsitance 401.1559459618874
# Ran else
# dsitance 412.6120153323535
# Ran else
# dsitance 238.09583193935296
# Ran else
# dsitance 398.4120382592829
# Ran else
# dsitance 395.58566082014744
# Ran else
# dsitance 206.4848259021261
# Ran else
# dsitance 393.0085432803951
# Ran else
# dsitance 334.81261265568565
# Ran else
# dsitance 391.63551782595266
# Ran else
# dsitance 314.95703938195794
# Ran else
# dsitance 266.64890253037197
# Ran else
# dsitance 276.4446917699962
# Ran else
# dsitance 384.7078871461471
# Ran else
# dsitance 383.9148326529416
# Ran else
# dsitance 183.49389723498126
# Ran else
# dsitance 383.1179764097985
# Ran else
# dsitance 276.0208694656084
# Ran else
# dsitance 376.87391711498805
# Ran else
# dsitance 246.04881042881345
# Ran else
# dsitance 263.34199054779754
# Ran else
# dsitance 372.9268845411835
# Ran else
# dsitance 255.38338201978368
# Ran else
# dsitance 367.0046308750869
# Ran else
# dsitance 265.90628723761876
# Ran else
# dsitance 294.9093144127529
# Ran else
# dsitance 365.79560335249323
# Ran else
# dsitance 364.5145536737854
# Ran else
# dsitance 298.4737242314507
# Ran else
# dsitance 359.3962595714015
# Ran else
# dsitance 358.86394802775243
# Ran else
# dsitance 358.33985596311453
# Ran else
# dsitance 357.2692009047092
# Ran else
# dsitance 265.07024394531635
# Ran else
# dsitance 356.6970177489744
# Ran else
# dsitance 355.390990887678
# Ran else
# dsitance 255.74490880272975
# Ran else
# dsitance 183.8804058589429
# Ran else
# dsitance 352.8941989178436
# Ran else
# dsitance 241.86229980009864
# Ran else
# dsitance 350.821496231786
# Ran else
# dsitance 445.44445154187116
# Ran else
# dsitance 289.69654363385547
# Ran else
# dsitance 261.66203622066905
# Ran else
# dsitance 349.00459345478953
# Ran else
# dsitance 347.2926714412415
# Ran else
# dsitance 330.50807561800855
# Ran else
# dsitance 345.4588471251072
# Ran else
# dsitance 285.36058393133703
# Ran else
# dsitance 278.91614151847347
# Ran else
# dsitance 466.2288727377746
# Ran else
# dsitance 343.65118346222937
# Ran else
# dsitance 285.3572387519256
# Ran else
# dsitance 341.4428115983799
# Ran else
# dsitance 263.77509452516085
# Ran else
# dsitance 230.70773434412797
# Ran else
# dsitance 340.00607906995964
# Ran else
# dsitance 286.1087928868689
# Ran else
# dsitance 310.13585158079655
# Ran else
# dsitance 286.36344799147145
# Ran else
# dsitance 338.14495359092797
# Ran else
# dsitance 337.90551449620335
# Ran else
# dsitance 305.5430170745254
# Ran else
# dsitance 337.2780318083068
# Ran else
# dsitance 274.1262448345801
# Ran else
# dsitance 299.79697462914714
# Ran else
# dsitance 254.37876785986685
# Ran else
# dsitance 348.09116658659286
# Ran else
# dsitance 335.1143868028729
# Ran else
# dsitance 334.537041882714
# Ran else
# dsitance 333.94673910086885
# Ran else
# dsitance 301.1560839917761
# Ran else
# dsitance 307.71478667138103
# Ran else
# dsitance 270.70050998368424
# Ran else
# dsitance 332.10549009501955
# Ran else
# dsitance 301.97252675337944
# Ran else
# dsitance 330.3136047226708
# Ran else
# dsitance 370.2458349045235
# Ran else
# dsitance 329.6990900818949
# Ran else
# dsitance 304.44325235615844
# Ran else
# dsitance 326.6711604264273
# Ran else
# dsitance 311.52208980294137
# Ran else
# dsitance 356.375660265158
# Ran else
# dsitance 321.7970521698393
# Ran else
# dsitance 341.4414721894304
# Ran else
# dsitance 293.1598677204492
# Ran else
# dsitance 416.4927930137648
# Ran else
# dsitance 217.90516886837165
# Ran else
# dsitance 287.72579952604394
# Ran else
# dsitance 214.18166705980948
# Ran else
# dsitance 311.7230319725388
# Ran else
# dsitance 53.59467155143725
# Ran else
# dsitance 244.74223581334618
# Ran else
# dsitance 143.86753580513192
# Ran else
# dsitance 175.50611926165112
# Ran else
# dsitance 113.43918212103064
# Ran else
# dsitance 126.78404600577826
# Ran else
# dsitance 74.17953751016157
# Ran else
# dsitance 82.69700821555026
# Ran else
# dsitance 53.925655603481864
# Ran else
# dsitance 87.8712667536753
# Ran else
# dsitance 94.95625033085322
# Ran else
# dsitance 32.93379570095526
# Ran else
# dsitance 214.69923385123084
# Ran else
# dsitance 54.633191063424846
# Ran else
# dsitance 73.11225378963769
# Ran else
# dsitance 75.0619053366719
# Ran else
# dsitance 116.82629313099183
# Ran else
# dsitance 240.3363077297247
# Ran else
# dsitance 170.945751364742
# Ran else
# dsitance 132.6806711923758
# Ran else
# dsitance 172.63180587801116
# Ran else
# dsitance 237.12396312463338
# Ran else
# dsitance 71.35463958551532
# Ran else
# dsitance 148.3049127350016
# Ran else
# dsitance 133.50326917570365
# Ran else
# dsitance 113.83432554081337
# Ran else
# dsitance 203.9445095513481
# Ran else
# dsitance 103.87646255886071
# Ran else
# dsitance 224.65211463710622
# Ran else
# dsitance 108.02829933745295
# Ran else
# dsitance 90.61052747810433
# Ran else
# dsitance 201.48289672227588
# Ran else
# dsitance 239.42095837281232
# Ran else
# dsitance 234.26294925503208
# Ran else
# dsitance 233.12131841732688
# Ran else
# dsitance 243.9819358754982
# Ran else
# dsitance 109.1304645355795
# Ran else
# dsitance 231.00123840690952
# Ran else
# dsitance 228.8566834531036
# Ran else
# dsitance 109.70997932330287
# Ran else
# dsitance 226.9511936272907
# Ran else
# dsitance 175.97434576952855
# Ran else
# dsitance 225.94684214446195
# Ran else
# dsitance 160.54957123701487
# Ran else
# dsitance 128.80324634119202
# Ran else
# dsitance 134.8271523318138
# Ran else
# dsitance 221.06192779952482
# Ran else
# dsitance 220.5397794850141
# Ran else
# dsitance 129.31611848642999
# Ran else
# dsitance 220.00366577476095
# Ran else
# dsitance 141.06643148663096
# Ran else
# dsitance 215.98832817709115
# Ran else
# dsitance 130.08890455777635
# Ran else
# dsitance 137.02980946499517
# Ran else
# dsitance 213.6472302262673
# Ran else
# dsitance 138.59753812844284
# Ran else
# dsitance 210.5206084259771
# Ran else
# dsitance 143.40419036111496
# Ran else
# dsitance 157.91237462260742
# Ran else
# dsitance 209.92515015592775
# Ran else
# dsitance 209.31759684919774
# Ran else
# dsitance 163.81540828065084
# Ran else
# dsitance 207.0393290168366
# Ran else
# dsitance 206.85474042893915
# Ran else
# dsitance 206.6603589727475
# Ran else
# dsitance 206.23194712923654
# Ran else
# dsitance 153.7873363484912
# Ran else
# dsitance 206.04386358352104
# Ran else
# dsitance 205.60228962791703
# Ran else
# dsitance 151.93603878863388
# Ran else
# dsitance 178.16813071226633
# Ran else
# dsitance 204.83164966121217
# Ran else
# dsitance 155.4730112052966
# Ran else
# dsitance 204.31697136914966
# Ran else
# dsitance 283.89418443119916
# Ran else
# dsitance 169.16728648284698
# Ran else
# dsitance 159.29493012963175
# Ran else
# dsitance 203.94271476294819
# Ran else
# dsitance 203.60355947933638
# Ran else
# dsitance 192.6270536761204
# Ran else
# dsitance 203.3714134778776
# Ran else
# dsitance 171.26386519775215
# Ran else
# dsitance 167.72484814308424
# Ran else
# dsitance 304.45429614199406
# Ran else
# dsitance 203.1620683728934
# Ran else
# dsitance 172.34880293573576
# Ran else
# dsitance 202.48743294038533
# Ran else
# dsitance 169.60269033792622
# Ran else
# dsitance 170.0329365134709
# Ran else
# dsitance 202.46295771277582
# Ran else
# dsitance 175.64579946878217
# Ran else
# dsitance 185.56753605296848
# Ran else
# dsitance 176.66320295672813
# Ran else
# dsitance 202.73082335486643
# Ran else
# dsitance 203.2232147878135
# Ran else
# dsitance 185.40926093937892
# Ran else
# dsitance 203.31056462281208
# Ran else
# dsitance 176.71940303865642
# Ran else
# dsitance 186.3074566478964
# Ran else
# dsitance 176.16282065359417
# Ran else
# dsitance 211.5633880210437
# Ran else
# dsitance 203.6907371331004
# Ran else
# dsitance 203.79371517512655
# Ran else
# dsitance 203.91840775373572
# Ran else
# dsitance 187.90153290652393
# Ran else
# dsitance 191.0077981615152
# Ran else
# dsitance 180.6158139796541
# Ran else
# dsitance 204.42850010114512
# Ran else
# dsitance 189.2704789388777
# Ran else
# dsitance 205.125794621374
# Ran else
# dsitance 230.38157351849253
# Ran else
# dsitance 205.41331879896924
# Ran else
# dsitance 196.11618299972233
# Ran else
# dsitance 207.3021231619938
# Ran else
# dsitance 199.41080126584404
# Ran else
# dsitance 225.10513431267103
# Ran else
# dsitance 207.98816670516675
# Ran else
# dsitance 216.65366574011975
# Ran else
# dsitance 197.06862123434826
# Ran else
# dsitance 269.7862647626271
# Ran else
# dsitance 229.58362526972206
# Ran else
# dsitance 198.493067648824
# Ran else
# dsitance 240.21680724910192
# Ran else
# dsitance 205.18169461102977
# Ran else
# dsitance 140.17271864432786
# Ran else
# dsitance 357.9363154964965
# Ran else
# dsitance 43.45598615203888
# Ran else
# dsitance 288.8964212383154
# Ran else
# dsitance 113.43918212103064
# Ran else
# dsitance 13.369943530003077
# overlap perc 0.2572253594442735
# acceptable or no overlap:  True
# dsitance 185.45477716755485
# Ran else
# dsitance 194.056026510234
# Ran else
# dsitance 62.43654164904529
# Ran else
# dsitance 198.58979429067423
# Ran else
# dsitance 205.76314458855558
# Ran else
# dsitance 97.88488373852528
# Ran else
# dsitance 325.6382871876764
# Ran else
# dsitance 155.77039057547077
# Ran else
# dsitance 177.23054791598477
# Ran else
# dsitance 55.64783542723084
# Ran else
# dsitance 223.2138754827
# Ran else
# dsitance 349.74371060152885
# Ran else
# dsitance 63.62799876989321
# Ran else
# dsitance 237.37723697668508
# Ran else
# dsitance 278.01243305299045
# Ran else
# dsitance 344.37365701248
# Ran else
# dsitance 115.73647519719961
# Ran else
# dsitance 249.2730483608465
# Ran else
# dsitance 61.560914747202645
# Ran else
# dsitance 67.18005849715772
# Ran else
# dsitance 99.61627241382118
# Ran else
# dsitance 83.9022014480715
# Ran else
# dsitance 327.853793194338
# Ran else
# dsitance 94.12073289454375
# Ran else
# dsitance 136.67141818489466
# Ran else
# dsitance 105.24819612798518
# Ran else
# dsitance 135.4815399459612
# Ran else
# dsitance 132.86364197597047
# Ran else
# dsitance 132.35386555711864
# Ran else
# dsitance 141.51696152034924
# Ran else
# dsitance 121.99018491526519
# Ran else
# dsitance 131.49727669428668
# Ran else
# dsitance 130.74238611722052
# Ran else
# dsitance 155.23627978960874
# Ran else
# dsitance 130.2073557677592
# Ran else
# dsitance 102.25341796274077
# Ran else
# dsitance 129.95843126398333
# Ran else
# dsitance 101.09132568229376
# Ran else
# dsitance 114.92677073745696
# Ran else
# dsitance 111.28471923268238
# Ran else
# dsitance 129.25977266531322
# Ran else
# dsitance 129.2850709145582
# Ran else
# dsitance 193.61787761724548
# Ran else
# dsitance 129.28100688648672
# Ran else
# dsitance 123.58765957286424
# Ran else
# dsitance 129.77049560779142
# Ran else
# dsitance 142.99625422760926
# Ran else
# dsitance 133.45149152663907
# Ran else
# dsitance 130.61000380666658
# Ran else
# dsitance 145.3598205461744
# Ran else
# dsitance 132.8396197352287
# Ran else
# dsitance 140.7516395068693
# Ran else
# dsitance 128.51852818638307
# Ran else
# dsitance 133.39505419914852
# Ran else
# dsitance 134.0374916099406
# Ran else
# dsitance 134.9800326640594
# Ran else
# dsitance 136.91511194294
# Ran else
# dsitance 137.33399810509587
# Ran else
# dsitance 137.71451632487117
# Ran else
# dsitance 138.41294571805543
# Ran else
# dsitance 158.2766355953833
# Ran else
# dsitance 138.88021314142148
# Ran else
# dsitance 139.90959627702162
# Ran else
# dsitance 165.06288880132453
# Ran else
# dsitance 248.63551288970245
# Ran else
# dsitance 142.01519940292806
# Ran else
# dsitance 182.86375818780067
# Ran else
# dsitance 144.01129755113635
# Ran else
# dsitance 189.93445742953548
# Ran else
# dsitance 156.0203654972102
# Ran else
# dsitance 170.2283626667895
# Ran else
# dsitance 145.9006551453441
# Ran else
# dsitance 147.67996162511236
# Ran else
# dsitance 148.24796928955394
# Ran else
# dsitance 149.83766659230164
# Ran else
# dsitance 164.547168087217
# Ran else
# dsitance 165.71311839788098
# Ran else
# dsitance 209.0085413281292
# Ran else
# dsitance 151.96652892666157
# Ran else
# dsitance 166.36492077467733
# Ran else
# dsitance 153.6330495462843
# Ran else
# dsitance 183.68386669714124
# Ran else
# dsitance 211.01132006324144
# Ran else
# dsitance 155.5655415269058
# Ran else
# dsitance 171.0324947701106
# Ran else
# dsitance 160.99813076650062
# Ran else
# dsitance 172.4440151278674
# Ran else
# dsitance 158.63843678872
# Ran else
# dsitance 159.96246245851933
# Ran else
# dsitance 166.18460815342823
# Ran else
# dsitance 160.9691427211955
# Ran else
# dsitance 184.8046690159857
# Ran else
# dsitance 174.25335936037501
# Ran else
# dsitance 201.35228262819194
# Ran else
# dsitance 163.53660620747138
# Ran else
# dsitance 164.5422687047751
# Ran else
# dsitance 165.483817884464
# Ran else
# dsitance 166.47831107881717
# Ran else
# dsitance 175.5163029638992
# Ran else
# dsitance 173.67825420161267
# Ran else
# dsitance 193.9104195201324
# Ran else
# dsitance 169.7722736794792
# Ran else
# dsitance 176.9884570136571
# Ran else
# dsitance 173.29420853563255
# Ran else
# dsitance 173.48649892429776
# Ran else
# dsitance 174.57649874926156
# Ran else
# dsitance 186.0815838366155
# Ran else
# dsitance 181.62899155396292
# Ran else
# dsitance 184.2642785601864
# Ran else
# dsitance 180.4492370556132
# Ran else
# dsitance 188.29033323902067
# Ran else
# dsitance 182.01244294670312
# Ran else
# dsitance 198.83993289056525
# Ran else
# dsitance 197.38972140373969
# Ran else
# dsitance 295.11535933301906
# Ran else
# dsitance 206.08690006919892
# Ran else
# dsitance 310.38386040219655
# Ran else
# dsitance 194.0154157536974
# Ran else
# 27.121257976570632
# dsitance 152.40039768555584
# Ran else
# dsitance 371.21491718076453
# Ran else
# dsitance 36.1720879490215
# Ran else
# dsitance 302.255155596708
# Ran else
# dsitance 126.78404600577826
# Ran else
# dsitance 13.369943530003077
# overlap perc 0.2572253594442735
# acceptable or no overlap:  True
# dsitance 198.80379502126746
# Ran else
# dsitance 207.4038053586159
# Ran else
# dsitance 75.6928929299484
# Ran else
# dsitance 211.91975895851184
# Ran else
# dsitance 219.0922393339826
# Ran else
# dsitance 110.99216380755472
# Ran else
# dsitance 338.9369319658468
# Ran else
# dsitance 168.90492721740668
# Ran else
# dsitance 190.38169224764735
# Ran else
# dsitance 67.42283609987572
# Ran else
# dsitance 236.36355619837605
# Ran else
# dsitance 362.9577179850238
# Ran else
# dsitance 53.26884594068888
# Ran else
# dsitance 250.4282598922514
# Ran else
# dsitance 291.04674549513436
# Ran else
# dsitance 357.46501628945987
# Ran else
# dsitance 127.20949294354523
# Ran else
# dsitance 262.10858296166555
# Ran else
# dsitance 62.75078920178008
# Ran else
# dsitance 72.96178439448562
# Ran else
# dsitance 89.36737914995739
# Ran else
# dsitance 91.75053869579196
# Ran else
# dsitance 340.70639714966893
# Ran else
# dsitance 101.80374007306837
# Ran else
# dsitance 147.5070827870147
# Ran else
# dsitance 97.0993452710071
# Ran else
# dsitance 124.85321752031379
# Ran else
# dsitance 122.89083259588132
# Ran else
# dsitance 122.54151899058554
# Ran else
# dsitance 131.18833258909416
# Ran else
# dsitance 130.75375714463215
# Ran else
# dsitance 122.00225055838044
# Ran else
# dsitance 121.59128196170377
# Ran else
# dsitance 165.52635817214764
# Ran else
# dsitance 121.38935346360934
# Ran else
# dsitance 99.51240007149934
# Ran else
# dsitance 121.32200129789526
# Ran else
# dsitance 101.27086180739514
# Ran else
# dsitance 121.19366017431393
# Ran else
# dsitance 116.53310496102795
# Ran else
# dsitance 121.59918686124497
# Ran else
# dsitance 121.74732905481187
# Ran else
# dsitance 204.54323812304654
# Ran else
# dsitance 121.8627216319322
# Ran else
# dsitance 128.9439514119848
# Ran else
# dsitance 123.32965646619365
# Ran else
# dsitance 150.89169476205637
# Ran else
# dsitance 140.0003206116707
# Ran else
# dsitance 124.82286191474124
# Ran else
# dsitance 152.55303023891432
# Ran else
# dsitance 128.0857023508113
# Ran else
# dsitance 147.10543959072456
# Ran else
# dsitance 132.05628687296436
# Ran else
# dsitance 128.85367711927222
# Ran else
# dsitance 129.7229709975255
# Ran else
# dsitance 138.31075359964305
# Ran else
# dsitance 133.49942396483806
# Ran else
# dsitance 134.01794412232408
# Ran else
# dsitance 134.493371233832
# Ran else
# dsitance 135.37769053811346
# Ran else
# dsitance 164.80255885982197
# Ran else
# dsitance 135.95020670083338
# Ran else
# dsitance 137.21388878906149
# Ran else
# dsitance 172.2841927258263
# Ran else
# dsitance 259.4767447803214
# Ran else
# dsitance 139.7649155901303
# Ran else
# dsitance 191.02100797751683
# Ran else
# dsitance 142.13476072724697
# Ran else
# dsitance 180.9811743778881
# Ran else
# dsitance 160.6042571778071
# Ran else
# dsitance 177.08799363036474
# Ran else
# dsitance 144.35061006851916
# Ran else
# dsitance 146.42887546033248
# Ran else
# dsitance 148.81695245734454
# Ran else
# dsitance 148.91230686220953
# Ran else
# dsitance 169.63421869470417
# Ran else
# dsitance 171.30521638574243
# Ran else
# dsitance 199.6172834113643
# Ran else
# dsitance 151.3526348033576
# Ran else
# dsitance 171.48453934818377
# Ran else
# dsitance 153.33872301660867
# Ran else
# dsitance 190.53709729059926
# Ran else
# dsitance 219.88185134591956
# Ran else
# dsitance 155.5173995414734
# Ran else
# dsitance 176.18032486649443
# Ran else
# dsitance 163.9751028745652
# Ran else
# dsitance 177.5991427264898
# Ran else
# dsitance 158.92752272875148
# Ran else
# dsitance 160.33818993863994
# Ran else
# dsitance 169.70093711333536
# Ran else
# dsitance 161.4532197308428
# Ran else
# dsitance 191.01069564770626
# Ran else
# dsitance 178.43709290097254
# Ran else
# dsitance 208.94310812097112
# Ran else
# dsitance 163.08889206836375
# Ran else
# dsitance 165.39484287139112
# Ran else
# dsitance 166.43169538634268
# Ran else
# dsitance 167.52396382225416
# Ran else
# dsitance 179.626907076344
# Ran else
# dsitance 177.22723252368417
# Ran else
# dsitance 200.4641020939959
# Ran else
# dsitance 171.1240645608266
# Ran else
# dsitance 181.07367464497963
# Ran else
# dsitance 174.9464281396538
# Ran else
# dsitance 171.39857135166588
# Ran else
# dsitance 176.33224883382647
# Ran else
# dsitance 190.2159970319596
# Ran else
# dsitance 183.9036083135053
# Ran else
# dsitance 187.82015567636677
# Ran else
# dsitance 180.0941146000919
# Ran else
# dsitance 191.1831763104718
# Ran else
# dsitance 183.0612876714064
# Ran else
# dsitance 204.05939983509774
# Ran else
# dsitance 192.29918304923507
# Ran else
# dsitance 305.2723871109999
# Ran else
# dsitance 211.803458931575
# Ran else
# dsitance 320.84356658838465
# Ran else
# dsitance 197.8372003163465
# Ran else
# dsitance 90.80970417901045
# Ran else
# dsitance 178.39674467510338
# Ran else
# dsitance 217.93546866321765
# Ran else
# dsitance 105.98880722144654
# Ran else
# dsitance 74.17953751016157
# Ran else
# dsitance 185.45477716755485
# Ran else
# dsitance 198.80379502126746
# Ran else
# dsitance 8.606617191563489
# overlap perc 0.521854600468695
# overlap is:  True
# dsitance 123.36373264791017
# Ran else
# dsitance 13.79536359918758
# overlap perc 0.23359091115624558
# acceptable or no overlap:  True
# dsitance 20.788949092302147
# Ran else
# dsitance 89.97919968705864
# Ran else
# dsitance 140.66815164400694
# Ran else
# dsitance 37.805403572609904
# Ran else
# dsitance 24.92936534705974
# Ran else
# dsitance 138.8368024516286
# Ran else
# dsitance 45.99410525532381
# Ran else
# dsitance 166.16579778212122
# Ran else
# dsitance 238.53284997832654
# Ran else
# dsitance 62.61097445976501
# Ran else
# dsitance 100.43226328583789
# Ran else
# dsitance 163.39639220435922
# Ran else
# dsitance 101.62725209206086
# Ran else
# dsitance 81.08447177128939
# Ran else
# dsitance 193.10192511744165
# Ran else
# dsitance 169.7378551113634
# Ran else
# dsitance 268.91186812407744
# Ran else
# dsitance 152.62863978054898
# Ran else
# dsitance 152.93603630720423
# Ran else
# dsitance 152.19988924748145
# Ran else
# dsitance 105.45768037541221
# Ran else
# dsitance 262.7939048864415
# Ran else
# dsitance 303.06084044996237
# Ran else
# dsitance 296.67280601960954
# Ran else
# dsitance 295.2364932469769
# Ran else
# dsitance 306.664537048596
# Ran else
# dsitance 137.95508539737153
# Ran else
# dsitance 292.5368798167045
# Ran else
# dsitance 289.76871631155893
# Ran else
# dsitance 114.29303027989201
# Ran else
# dsitance 287.25794609826755
# Ran else
# dsitance 229.92823319938287
# Ran else
# dsitance 285.92474135066294
# Ran else
# dsitance 210.75347215779752
# Ran else
# dsitance 165.37743705636092
# Ran else
# dsitance 174.49785114934312
# Ran else
# dsitance 279.25579230742693
# Ran else
# dsitance 278.50150388205117
# Ran else
# dsitance 107.95868051318227
# Ran else
# dsitance 277.7426680474768
# Ran else
# dsitance 175.8709450720449
# Ran else
# dsitance 271.8548148864122
# Ran else
# dsitance 150.4677221438184
# Ran else
# dsitance 165.2957265772784
# Ran else
# dsitance 268.19501812360744
# Ran else
# dsitance 160.0915091132455
# Ran else
# dsitance 262.82455011763244
# Ran else
# dsitance 169.22063048169804
# Ran else
# dsitance 194.74432904810115
# Ran else
# dsitance 261.7441743736888
# Ran else
# dsitance 260.6072984801781
# Ran else
# dsitance 199.10953362731965
# Ran else
# dsitance 256.1268875540481
# Ran else
# dsitance 255.6764134685641
# Ran else
# dsitance 255.23028364914344
# Ran else
# dsitance 254.31246703062257
# Ran else
# dsitance 172.3322088184493
# Ran else
# dsitance 253.83331702815988
# Ran else
# dsitance 252.7389519258294
# Ran else
# dsitance 165.3296284324058
# Ran else
# dsitance 138.61846971653299
# Ran else
# dsitance 250.67585932056497
# Ran else
# dsitance 157.7815790577621
# Ran else
# dsitance 249.00750282837146
# Ran else
# dsitance 340.5508130453875
# Ran else
# dsitance 194.73506292968776
# Ran else
# dsitance 172.20849282090535
# Ran else
# dsitance 247.5749661016108
# Ran else
# dsitance 246.236331526778
# Ran else
# dsitance 230.91495663085007
# Ran else
# dsitance 244.8491562201129
# Ran else
# dsitance 192.5808192539268
# Ran else
# dsitance 186.94087489898502
# Ran else
# dsitance 361.34837982117233
# Ran else
# dsitance 243.49649921088053
# Ran else
# dsitance 192.99045682604023
# Ran else
# dsitance 241.72411702236965
# Ran else
# dsitance 177.89324275333752
# Ran else
# dsitance 158.12842335692935
# Ran else
# dsitance 240.70593892417844
# Ran else
# dsitance 194.75881155334764
# Ran else
# dsitance 214.4600828239021
# Ran else
# dsitance 195.3240052555822
# Ran else
# dsitance 239.49383127654818
# Ran else
# dsitance 239.48916017894126
# Ran else
# dsitance 211.3139375064085
# Ran else
# dsitance 239.08458637947672
# Ran else
# dsitance 187.4882407246077
# Ran else
# dsitance 207.85863301695002
# Ran else
# dsitance 175.09403622679113
# Ran else
# dsitance 249.26985533294734
# Ran else
# dsitance 237.7282223027114
# Ran else
# dsitance 237.37004592683914
# Ran else
# dsitance 237.01190415458458
# Ran else
# dsitance 209.3625067956487
# Ran else
# dsitance 214.8421661385884
# Ran else
# dsitance 187.05581154931002
# Ran else
# dsitance 235.946858756031
# Ran else
# dsitance 210.4260576477381
# Ran else
# dsitance 234.99765347664896
# Ran else
# dsitance 270.7077334620384
# Ran else
# dsitance 234.69369755533123
# Ran else
# dsitance 214.73433376093928
# Ran else
# dsitance 233.40681385904023
# Ran else
# dsitance 220.56993073938378
# Ran else
# dsitance 259.4919224558684
# Ran else
# dsitance 230.5310771122173
# Ran else
# dsitance 246.55482105383476
# Ran else
# dsitance 208.0969858582405
# Ran else
# dsitance 315.332221402741
# Ran else
# dsitance 187.94844099301864
# Ran else
# dsitance 205.4390534146236
# Ran else
# dsitance 193.79550784336573
# Ran else
# dsitance 223.03073302508204
# Ran else
# dsitance 97.09807411374544
# Ran else
# dsitance 170.49311570086894
# Ran else
# dsitance 226.4942039946793
# Ran else
# dsitance 97.83118193647059
# Ran else
# dsitance 82.69700821555026
# Ran else
# dsitance 194.056026510234
# Ran else
# dsitance 207.4038053586159
# Ran else
# dsitance 8.606617191563489
# overlap perc 0.521854600468695
# overlap is:  True
# dsitance 131.9449372724866
# Ran else
# dsitance 6.04557028697788
# overlap perc 0.6641349840567844
# overlap is:  True
# dsitance 12.446494433534125
# overlap perc 0.3085280870258819
# acceptable or no overlap:  True
# dsitance 98.42373353506969
# Ran else
# dsitance 132.08659564996987
# Ran else
# dsitance 45.011810110725335
# Ran else
# dsitance 29.127847282465762
# Ran else
# dsitance 147.2375626313007
# Ran else
# dsitance 39.422192820356486
# Ran else
# dsitance 157.6913843260098
# Ran else
# dsitance 246.9685745672885
# Ran else
# dsitance 55.97576274461191
# Ran else
# dsitance 92.78711964144172
# Ran else
# dsitance 155.15658706025644
# Ran else
# dsitance 108.7193220455876
# Ran else
# dsitance 75.04121983064992
# Ran else
# dsitance 201.17870273963982
# Ran else
# dsitance 177.67611056759273
# Ran else
# dsitance 277.19283513727385
# Ran else
# dsitance 160.2379327170103
# Ran else
# dsitance 145.30127420705654
# Ran else
# dsitance 159.5293049857319
# Ran else
# dsitance 111.32059238656579
# Ran else
# dsitance 270.86309347071665
# Ran else
# dsitance 311.2401990688126
# Ran else
# dsitance 304.7797454347066
# Ran else
# dsitance 303.3258465959045
# Ran else
# dsitance 314.7813609651934
# Ran else
# dsitance 144.34966638346307
# Ran else
# dsitance 300.59137439346057
# Ran else
# dsitance 297.7853423353225
# Ran else
# dsitance 118.99984834233521
# Ran else
# dsitance 295.2374264846297
# Ran else
# dsitance 237.5730701708764
# Ran else
# dsitance 293.8839205427404
# Ran else
# dsitance 218.19567260774477
# Ran else
# dsitance 172.0809166473987
# Ran else
# dsitance 181.36412587066948
# Ran else
# dsitance 287.10321656153826
# Ran else
# dsitance 286.33412968354963
# Ran else
# dsitance 109.82076972025766
# Ran else
# dsitance 285.5611142530528
# Ran else
# dsitance 182.36159509720764
# Ran else
# dsitance 279.5524477627041
# Ran else
# dsitance 156.01520309140867
# Ran else
# dsitance 171.35146417154394
# Ran else
# dsitance 275.80586264464125
# Ran else
# dsitance 165.6258929020956
# Ran else
# dsitance 270.28437690594257
# Ran else
# dsitance 175.03644368166098
# Ran else
# dsitance 201.27222666629095
# Ran else
# dsitance 269.17090142420375
# Ran else
# dsitance 267.99768341872965
# Ran else
# dsitance 205.49053334834105
# Ran else
# dsitance 263.3641420202125
# Ran else
# dsitance 262.89481568199153
# Ran else
# dsitance 262.43084949978953
# Ran else
# dsitance 261.47839426357245
# Ran else
# dsitance 177.47740548271236
# Ran else
# dsitance 260.9784243477997
# Ran else
# dsitance 259.8372601918411
# Ran else
# dsitance 170.06509308666415
# Ran else
# dsitance 137.19787904311517
# Ran else
# dsitance 257.68061402804636
# Ran else
# dsitance 161.4927913982941
# Ran else
# dsitance 255.92755467445508
# Ran else
# dsitance 348.22328345449944
# Ran else
# dsitance 200.32518579010886
# Ran else
# dsitance 176.82446550674422
# Ran else
# dsitance 254.41642179063817
# Ran else
# dsitance 253.00297267727882
# Ran else
# dsitance 237.38688236984564
# Ran else
# dsitance 251.52816873597038
# Ran else
# dsitance 197.8056261727587
# Ran else
# dsitance 192.01720998632575
# Ran else
# dsitance 369.0201597776636
# Ran else
# dsitance 250.08798690000987
# Ran else
# dsitance 198.15027119987235
# Ran else
# dsitance 248.23258950436855
# Ran else
# dsitance 181.9934629807351
# Ran else
# dsitance 160.22892940048206
# Ran else
# dsitance 247.1366584515999
# Ran else
# dsitance 199.76350254008236
# Ran else
# dsitance 220.218173192999
# Ran else
# dsitance 200.2820653506522
# Ran else
# dsitance 245.8065364142201
# Ran else
# dsitance 245.76035782303222
# Ran else
# dsitance 216.82644432792281
# Ran else
# dsitance 245.3160966214807
# Ran else
# dsitance 191.74722047769632
# Ran else
# dsitance 212.99711990395542
# Ran else
# dsitance 178.23533517319387
# Ran else
# dsitance 255.62537375831013
# Ran else
# dsitance 243.81816301743575
# Ran else
# dsitance 243.4220725158832
# Ran else
# dsitance 243.0240230220302
# Ran else
# dsitance 214.48284900362086
# Ran else
# dsitance 220.14667468684837
# Ran else
# dsitance 190.87836395414953
# Ran else
# dsitance 241.82732880217736
# Ran else
# dsitance 215.5111856044277
# Ran else
# dsitance 240.73808313821092
# Ran else
# dsitance 277.2143977767823
# Ran else
# dsitance 240.38321695799894
# Ran else
# dsitance 219.55292683349558
# Ran else
# dsitance 238.81732173375025
# Ran else
# dsitance 225.5930066352149
# Ran else
# dsitance 265.52924632098365
# Ran else
# dsitance 235.62800372003008
# Ran else
# dsitance 252.24727848330141
# Ran else
# dsitance 212.21631007283173
# Ran else
# dsitance 322.1699033917235
# Ran else
# dsitance 185.68710335931243
# Ran else
# dsitance 209.1597462486137
# Ran else
# dsitance 190.7520886921745
# Ran else
# dsitance 227.72435876780952
# Ran else
# dsitance 94.31559684743742
# Ran else
# dsitance 298.0855146608395
# Ran else
# dsitance 99.40896223774894
# Ran else
# dsitance 227.82360157580732
# Ran else
# dsitance 53.925655603481864
# Ran else
# dsitance 62.43654164904529
# Ran else
# dsitance 75.6928929299484
# Ran else
# dsitance 123.36373264791017
# Ran else
# dsitance 131.9449372724866
# Ran else
# dsitance 136.33836612520827
# Ran else
# dsitance 143.50440794948844
# Ran else
# dsitance 35.84332015761345
# Ran else
# dsitance 263.2583542112938
# Ran else
# dsitance 93.47504279938586
# Ran else
# dsitance 114.8878256196326
# Ran else
# dsitance 24.603468899502836
# Ran else
# dsitance 160.85893989816904
# Ran else
# dsitance 287.3126943825439
# Ran else
# dsitance 117.10384993974645
# Ran else
# dsitance 175.21951165078826
# Ran else
# dsitance 215.8741543949478
# Ran else
# dsitance 282.096624954886
# Ran else
# dsitance 64.21323699696629
# Ran else
# dsitance 187.73761011462372
# Ran else
# dsitance 82.03595781765132
# Ran else
# dsitance 66.091550229477
# Ran else
# dsitance 150.0575719143444
# Ran else
# dsitance 64.22403074534405
# Ran else
# dsitance 266.1810119637394
# Ran else
# dsitance 72.08118391372558
# Ran else
# dsitance 87.66411628733708
# Ran else
# dsitance 148.29451550508477
# Ran else
# dsitance 185.62723536932958
# Ran else
# dsitance 180.67777715567874
# Ran else
# dsitance 179.5987165492808
# Ran else
# dsitance 190.3236699623869
# Ran else
# dsitance 87.54868743129103
# Ran else
# dsitance 177.6147817575714
# Ran else
# dsitance 175.63524872800897
# Ran else
# dsitance 108.3428656297689
# Ran else
# dsitance 173.90694634166178
# Ran else
# dsitance 126.3898867080537
# Ran else
# dsitance 173.0057105937304
# Ran else
# dsitance 113.88905745053476
# Ran else
# dsitance 96.08134166878924
# Ran else
# dsitance 98.55113178897939
# Ran else
# dsitance 168.75612839417334
# Ran else
# dsitance 168.32494389648326
# Ran else
# dsitance 141.6206130070751
# Ran else
# dsitance 167.87827526177702
# Ran else
# dsitance 108.07788265021848
# Ran else
# dsitance 164.67778859525572
# Ran else
# dsitance 111.03907237581537
# Ran else
# dsitance 110.1272909548852
# Ran else
# dsitance 162.9705702375439
# Ran else
# dsitance 117.07506302738022
# Ran else
# dsitance 161.0156790785539
# Ran else
# dsitance 117.5590015896551
# Ran else
# dsitance 121.39594096274472
# Ran else
# dsitance 160.68762957682236
# Ran else
# dsitance 160.3768901422305
# Ran else
# dsitance 127.95832205554895
# Ran else
# dsitance 159.3873535886831
# Ran else
# dsitance 159.36198053234307
# Ran else
# dsitance 159.3199370104507
# Ran else
# dsitance 159.19202939174411
# Ran else
# dsitance 132.33404307679288
# Ran else
# dsitance 159.1825488771221
# Ran else
# dsitance 159.14667309611673
# Ran else
# dsitance 134.81322528103604
# Ran else
# dsitance 196.0274574818916
# Ran else
# dsitance 159.19360185889224
# Ran else
# dsitance 146.35819186984605
# Ran else
# dsitance 159.4207629539159
# Ran else
# dsitance 231.70372393391446
# Ran else
# dsitance 140.36298965572308
# Ran else
# dsitance 141.517829301341
# Ran else
# dsitance 159.73661498859613
# Ran else
# dsitance 160.0591474564403
# Ran else
# dsitance 152.5438676352596
# Ran else
# dsitance 160.59671339726074
# Ran else
# dsitance 145.5407171189005
# Ran else
# dsitance 144.0134600108209
# Ran else
# dsitance 252.08327114356456
# Ran else
# dsitance 161.1591511248908
# Ran else
# dsitance 147.0347000545252
# Ran else
# dsitance 161.25647375578342
# Ran else
# dsitance 154.07746927078202
# Ran else
# dsitance 169.42055202361112
# Ran else
# dsitance 161.911617099917
# Ran else
# dsitance 151.17052033520324
# Ran else
# dsitance 152.78479160609925
# Ran else
# dsitance 152.4320948148543
# Ran else
# dsitance 163.18700407479767
# Ran else
# dsitance 163.99973361086867
# Ran else
# dsitance 154.8799374589831
# Ran else
# dsitance 164.42510645442243
# Ran else
# dsitance 158.5031364381595
# Ran else
# dsitance 158.98404393238584
# Ran else
# dsitance 166.8961855852929
# Ran else
# dsitance 170.96235392837474
# Ran else
# dsitance 166.00251976681457
# Ran else
# dsitance 166.42516497710056
# Ran else
# dsitance 166.88438537922968
# Ran else
# dsitance 160.5109480709883
# Ran else
# dsitance 161.5858353394175
# Ran else
# dsitance 165.25257462482233
# Ran else
# dsitance 168.48476918292224
# Ran else
# dsitance 161.99522766440978
# Ran else
# dsitance 170.31874757394206
# Ran else
# dsitance 187.36728416334975
# Ran else
# dsitance 171.01372125498307
# Ran else
# dsitance 170.18422928439446
# Ran else
# dsitance 175.07768031883282
# Ran else
# dsitance 171.34084645939944
# Ran else
# dsitance 186.16583321574421
# Ran else
# dsitance 178.307319013494
# Ran else
# dsitance 181.19391372401853
# Ran else
# dsitance 176.7136619093713
# Ran else
# dsitance 222.7901854604835
# Ran else
# dsitance 245.24091850739075
# Ran else
# dsitance 181.05046088617493
# Ran else
# dsitance 258.90689751134687
# Ran else
# dsitance 179.13510268128624
# Ran else
# dsitance 103.14224103967187
# Ran else
# dsitance 167.92203233313464
# Ran else
# dsitance 231.52549403132812
# Ran else
# dsitance 94.89652749135409
# Ran else
# dsitance 87.8712667536753
# Ran else
# dsitance 198.58979429067423
# Ran else
# dsitance 211.91975895851184
# Ran else
# dsitance 13.79536359918758
# overlap perc 0.23359091115624558
# acceptable or no overlap:  True
# dsitance 6.04557028697788
# overlap perc 0.6641349840567844
# overlap is:  True
# dsitance 136.33836612520827
# Ran else
# dsitance 7.175066721111757
# overlap perc 0.6013851821604579
# overlap is:  True
# dsitance 102.36246939161607
# Ran else
# dsitance 127.21392746256056
# Ran else
# dsitance 47.41726705478842
# Ran else
# dsitance 29.424104373925566
# Ran else
# dsitance 151.01757728424468
# Ran else
# dsitance 33.39471383041969
# Ran else
# dsitance 152.46939956734036
# Ran else
# dsitance 250.79604621280976
# Ran else
# dsitance 49.93548753428351
# Ran else
# dsitance 86.8709751626776
# Ran else
# dsitance 149.60102982808036
# Ran else
# dsitance 110.6154364123727
# Ran else
# dsitance 69.05444833795434
# Ran else
# dsitance 204.2860762043982
# Ran else
# dsitance 180.57389953465147
# Ran else
# dsitance 280.6534408249298
# Ran else
# dsitance 162.68069617160023
# Ran else
# dsitance 139.38803615259292
# Ran else
# dsitance 161.61658742533456
# Ran else
# dsitance 111.96329940066998
# Ran else
# dsitance 273.9304923922168
# Ran else
# dsitance 314.4940399167783
# Ran else
# dsitance 307.90383468103397
# Ran else
# dsitance 306.4195539902642
# Ran else
# dsitance 317.9207391259116
# Ran else
# dsitance 145.43028664949912
# Ran else
# dsitance 303.6260017937223
# Ran else
# dsitance 300.75738373253705
# Ran else
# dsitance 118.61345151478906
# Ran else
# dsitance 298.14953189159735
# Ran else
# dsitance 240.01043438634395
# Ran else
# dsitance 296.76384290909544
# Ran else
# dsitance 220.37561246758943
# Ran else
# dsitance 173.44291171994178
# Ran else
# dsitance 182.89262917889735
# Ran else
# dsitance 289.8123275695052
# Ran else
# dsitance 289.0213341282491
# Ran else
# dsitance 107.37368794942948
# Ran else
# dsitance 288.2274885612093
# Ran else
# dsitance 183.48968427920548
# Ran else
# dsitance 282.0466126029834
# Ran else
# dsitance 156.27221656150303
# Ran else
# dsitance 172.05974391912346
# Ran else
# dsitance 278.1814569655159
# Ran else
# dsitance 165.85681166125286
# Ran else
# dsitance 272.4621639565717
# Ran else
# dsitance 175.51290083288416
# Ran else
# dsitance 202.4210412493527
# Ran else
# dsitance 271.30662736895835
# Ran else
# dsitance 270.08771059239047
# Ran else
# dsitance 206.4851235071632
# Ran else
# dsitance 265.2667913268498
# Ran else
# dsitance 264.7749024988416
# Ran else
# dsitance 264.2897016925305
# Ran else
# dsitance 263.2963120320145
# Ran else
# dsitance 177.34947296614044
# Ran else
# dsitance 262.7718801421001
# Ran else
# dsitance 261.57619975173805
# Ran else
# dsitance 169.60052307357088
# Ran else
# dsitance 132.7845866982007
# Ran else
# dsitance 259.3123397456513
# Ran else
# dsitance 160.23135555165044
# Ran else
# dsitance 257.4640765331192
# Ran else
# dsitance 350.66392797860357
# Ran else
# dsitance 200.56643282558798
# Ran else
# dsitance 176.2524294146329
# Ran else
# dsitance 255.8660969395985
# Ran else
# dsitance 254.37126846069347
# Ran else
# dsitance 238.4516476544654
# Ran else
# dsitance 252.80257135878387
# Ran else
# dsitance 197.72401046827153
# Ran else
# dsitance 191.8131352362357
# Ran else
# dsitance 371.45561993829926
# Ran else
# dsitance 251.27012936571148
# Ran else
# dsitance 198.01181308434266
# Ran else
# dsitance 249.32884056329937
# Ran else
# dsitance 181.00239030896293
# Ran else
# dsitance 157.82746731174583
# Ran else
# dsitance 248.15323095852293
# Ran else
# dsitance 199.49014967013292
# Ran else
# dsitance 220.5967671126403
# Ran else
# dsitance 199.96855002679547
# Ran else
# dsitance 246.70393055695408
# Ran else
# dsitance 246.61611795041048
# Ran else
# dsitance 216.98279767024462
# Ran else
# dsitance 246.1325325436379
# Ran else
# dsitance 190.86971443587515
# Ran else
# dsitance 212.8263431806203
# Ran else
# dsitance 176.52951661759118
# Ran else
# dsitance 256.56050709410243
# Ran else
# dsitance 244.49618125968217
# Ran else
# dsitance 244.06350454059907
# Ran else
# dsitance 243.62714738491317
# Ran else
# dsitance 214.29510933206126
# Ran else
# dsitance 220.11486520159008
# Ran else
# dsitance 189.66250014549158
# Ran else
# dsitance 242.30551236817757
# Ran else
# dsitance 215.292219649301
# Ran else
# dsitance 241.0856527222677
# Ran else
# dsitance 278.2942230312918
# Ran else
# dsitance 240.68386177779462
# Ran else
# dsitance 219.10442428717587
# Ran else
# dsitance 238.86572762438837
# Ran else
# dsitance 225.31262069885773
# Ran else
# dsitance 266.1439029151371
# Ran else
# dsitance 235.40355726473226
# Ran else
# dsitance 252.5432183026842
# Ran else
# dsitance 211.20832400585496
# Ran else
# dsitance 323.58840962907306
# Ran else
# dsitance 180.83234446811272
# Ran else
# dsitance 207.8478703192883
# Ran else
# dsitance 185.5668597370232
# Ran else
# dsitance 227.16535200910891
# Ran else
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 364
#     356         target_flux_error = target_flux * np.log(10) * (Mcal_error/2.5)
#     359 else:
#     360         # to handle the cases where the counts are not more than 0 and if the conversion factors are missing.
#     361         rows.append({ 'band_id': {band_labels[band_id]}, 'Galaxy Name' : galaxy_name, 'ObsID' : obsid[0], 'Region': i+1, 'X': x, 'Y': y, 'Radius': r, 'Annulus_Inner_Radius': annulus_inner,
#     362         'Annulus_Outer_Radius': annulus_outer, 'Net Flux (Jy)': net_flx, 'Flux Uncertainty': [], 'Flag':'Negative Target Counts',
#     363         'aperture_sum': target_photo_table['aperture_sum'][0] ,'tot_bg': tot_bg, 'Target Counts': target_counts, 'Target Flux': target_flux,
# --> 364             'Annulus Counts': annulus_counts, 'Overlap Counts': overlap_counts, 'Annulus Flux': annulus_flux,'Image Data Shape': cutout_data.shape, 'Mask Shape': non_overlapping_mask.shape,
#     365             'Mask Type': non_overlapping_mask.dtype, 'Non-zero mask elements': np.count_nonzero(non_overlapping_mask), 'Flux Conv':flx_conv_fact, 'MzpInstr':M0instr,
#     366             'Offset in Arcseconds': [],  'Exists?': 'No', 'Point Source Position' : [], 'Target Error': target_flux_error, 'Annulus Error': annulus_flux_error, 'Overlap Error (in counts)': overlap_error, 'Wavelength': wavelengths[band_id], 'Flux Density': [], 'Flux Density Uncertainty' : []  })
#     370 #calculate area of target aperutue
#     371 target_area = target_aperture.area
#
# AttributeError: 'float' object has no attribute 'shape'
