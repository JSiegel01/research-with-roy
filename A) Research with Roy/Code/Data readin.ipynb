# %%
import numpy as np
import pandas as pd
import math
import glob
from astroquery.ipac.irsa import Irsa
from astropy.coordinates import SkyCoord
from astropy import units as u
from astroquery.simbad import Simbad
from astropy.table import Table

# %%
#Reading in the csv files
oldlongsample = pd.read_csv('../Data/ocatResult_Modified.csv')
targetsample = pd.read_csv('../Data/galaxy_names_reduced_homogeneous_resolved_unique_with_10ks_exposure_cut.csv')
print(targetsample)
targetsample = pd.DataFrame(targetsample['Galaxy_Name_Reduced'][:])

targetsample = targetsample.rename(columns={'Galaxy_Name_Reduced': 'source_id'})
#targetsample['source_id']

#target_data = target_data.rename(columns={'Gname': 'source_id'})
#target_data = target_data.rename(columns={'RA': 'ra'})
#target_data = target_data.rename(columns={'Dec': 'dec'})

#target_data = target_data.drop_duplicates(subset = ['source_id'])
# Out:
#      Unnamed: 0        Galaxy_Name_Reduced
# 0             0                   NGC 5128
# 1             1                MESSIER 086
# 2             2                MESSIER 106
# 3             3                MESSIER 051
# 4             4                MESSIER 082
# 5             5                   NGC 1569
# 6             6                   NGC 4697
# 7             7                   NGC 0253
# 8             8                    IC 2574
# 9             9                   NGC 0891
# 10           10     NGC 1291:[LFF2012] 084
# 11           11                   NGC 4631
# 12           12                MESSIER 094
# 13           13                   NGC 4945
# 14           14                   NGC 0404
# 15           15                  UGC 06456
# 16           16                   NGC 6503
# 17           17                   NGC 4395
# 18           18                MESSIER 101
# 19           19                   NGC 4244
# 20           20                   NGC 4111
# ...

# %%
data = pd.read_csv('../Data/1to1_irsa_catalog_search_results.csv')
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
#data

# %%
merged_data = pd.merge(targetsample, data, left_on=['ra', 'dec'], right_on= ['ra_01', 'dec_01'], how='left')
merged_data = merged_data.drop_duplicates()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/nd/77pj43rx7wbcbp0wx2qjq2140000gp/T/ipykernel_70961/2947698861.py in ?()
# ----> 1 merged_data = pd.merge(targetsample, data, left_on=['ra', 'dec'], right_on= ['ra_01', 'dec_01'], how='left')
#       2 merged_data = merged_data.drop_duplicates()
#
# ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     165             validate=validate,
#     166             copy=copy,
#     167         )
#     168     else:
# --> 169         op = _MergeOperation(
#     170             left_df,
#     171             right_df,
#     172             how=how,
#
# ...
